# %%
import sys
import os
import json

# Add the parent directory of the package to sys.path
sys.path.append(os.path.abspath('.'))
from solver.portion_solver import Portion_Solver

# Create an instance of Portion_Solver
solver = Portion_Solver()

# %%
path = "training_dataset/training_set_portion.json"

# %%
with open(path, 'r') as file:
    data = json.load(file)

# %%
def extract_data(data, stype_values):
        extracted_data = []
        for item in data:
            # Check if the 'stype' key exists and its value matches one of the specified values in stype_values
            if 'stype' in item and item['stype'] == stype_values:
                extracted_data.append(item)
        return extracted_data

# %%
import pandas as pd
from collections import Counter
stype_combinations = [tuple(d["stype"]) for d in data]
combination_counts = Counter(stype_combinations)

# Convert to DataFrame for better visualization
combination_df = pd.DataFrame(combination_counts.items(), columns=['Combination', 'Count'])
combination_df = combination_df.sort_values(by='Count', ascending=False)

combination_df
# Out:
#                 Combination  Count
# 0            (有, 每單位量, 問分配)     95
# 3       (有, 每單位量, 問分配, 問剩下)     17
# 12   (每單位量, 每單位量, 問分配, 問剩下)      8
# 6           (量變, 每單位量, 問分配)      7
# 16             (有, 平分, 問分配)      6
# 7      (有, 每單位量, 每單位量, 問分配)      6
# 9        (有, 量變, 每單位量, 問分配)      6
# 2      (量變, 每單位量, 問分配, 問剩下)      5
# 13           (每單位量, 有, 問分配)      4
# 15        (每單位量, 每單位量, 問分配)      3
# 5       (每單位量, 有, 問分配, 問剩下)      2
# 8       (量變, 量變, 每單位量, 問分配)      2
# 11     (每單位量, 有, 每單位量, 問分配)      2
# 4     (量變, 每單位量, 每單位量, 問分配)      2
# 1             (量變, 平分, 問分配)      1
# 10       (有, 每單位量, 剩下, 問分配)      1
# 14  (有, 量變, 每單位量, 問分配, 問剩下)      1
# 17          (每單位量, 量變, 問分配)      1
# 18     (每單位量, 量變, 問分配, 問剩下)      1

# %%
extracted_data = data

# %%
len(extracted_data)
# Out:
# 170

# %%
extracted_data
# Out:
# [{'qid': '61298',
#   'sentence': '有845朵玫瑰，平均每13朵分裝成一束，可裝成幾束？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '845', 'unit': '朵', 'entity': '玫瑰'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '13', 'unit': '朵', 'entity': '玫瑰'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '束', 'entity': '玫瑰'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '束', 'entity': '玫瑰'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '65束',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '61299',
#   'sentence': '老師買了512枝筆，想平均分給32位學生，每位學生最多會分到幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '512', 'unit': '枝', 'entity': '筆'},
#      'verb': '買',
#      'subject': '老師',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '32', 'unit': '位', 'entity': '學生'},
#      'verb': '分給',
#      'subject': '老師',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '學生'},
#      'verb': '最多',
#      'subject': '每',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '16枝',
#   'stype': ['量變', '平分', '問分配']},
#  {'qid': '1MA0141599',
#   'sentence': '清清果園收成9000顆百香果，每110顆裝一箱，可以裝成幾箱？還剩下多少顆百香果？',
#   'quantities': {'s1': [{'qtyid': 'E2',
#      'quantity': {'value': '9000', 'unit': '顆', 'entity': '百香果'},
#      'verb': '清',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '110', 'unit': '顆', 'entity': '百香果'},
#      'verb': '清',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '百香果'},
#      'verb': '清',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '百香果'},
#      'verb': '清',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E3',
#      'quantity': {'value': '多少', 'unit': '顆', 'entity': '百香果'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's4': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '81箱;90顆',
#   'stype': ['量變', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0142759',
#   'sentence': '有88朵玫瑰花，每16朵紮成一束，共可以紮成多少束？還剩下多少朵？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '88', 'unit': '朵', 'entity': '玫瑰花'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '16', 'unit': '朵', 'entity': '玫瑰花'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '束', 'entity': '玫瑰花'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '束', 'entity': '玫瑰花'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '朵', 'entity': '玫瑰花'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '5束;8朵',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '74248',
#   'sentence': '神奇文具工廠八月生產775000枝鉛筆，每1800枝裝成一箱，共裝成幾箱？剩下幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E2',
#      'quantity': {'value': '775000', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '神奇',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '1800', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '鉛筆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '鉛筆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '430箱;1000枝',
#   'stype': ['量變', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0142758',
#   'sentence': '有99個柚子，每19個裝一簍，可以裝成幾簍？還剩多少個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '99', 'unit': '個', 'entity': '柚子'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '19', 'unit': '個', 'entity': '柚子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '簍', 'entity': '柚子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '簍', 'entity': '柚子'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '個', 'entity': '柚子'},
#      'verb': '剩',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '5簍;4個',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '74243',
#   'sentence': '趣味模型製造工廠這個月生產36572架飛機模型，每100架裝一箱，可裝成幾箱？剩下幾架？',
#   'quantities': {'s1': [{'qtyid': 'E2',
#      'quantity': {'value': '36572', 'unit': '架', 'entity': '模型'},
#      'verb': '製造',
#      'subject': '模型',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '100', 'unit': '架', 'entity': '模型'},
#      'verb': '裝',
#      'subject': '模型',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '模型'},
#      'verb': '裝',
#      'subject': '模型',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '模型'},
#      'verb': '裝成',
#      'subject': '模型',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '架', 'entity': '模型'},
#      'verb': '剩下',
#      'subject': '模型',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '365箱;72架',
#   'stype': ['量變', '每單位量', '問分配', '問剩下']},
#  {'qid': '74459',
#   'sentence': '香香蛋糕店今天做120個鮮奶蛋糕，每6個裝成一盒，每5盒裝成一箱，共可裝成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '120', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '香香',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '6', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '蛋糕'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '5', 'unit': '盒', 'entity': '蛋糕'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '蛋糕'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '蛋糕'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '4箱',
#   'stype': ['量變', '每單位量', '每單位量', '問分配']},
#  {'qid': '1MA0142760',
#   'sentence': '每27顆珠子可以串成一條鍊子，家惠有99顆珠子，共可以串成多少條鍊子？還剩下多少顆？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '條', 'entity': '鍊子'},
#      'verb': '可以',
#      'subject': '珠子',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '27', 'unit': '顆', 'entity': '珠子'},
#      'verb': '可以',
#      'subject': '珠子',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '99', 'unit': '顆', 'entity': '珠子'},
#      'verb': '有',
#      'subject': '家惠',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '條', 'entity': '鍊子'},
#      'verb': '可以',
#      'subject': '家惠',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '顆', 'entity': '鍊子'},
#      'verb': '剩下',
#      'subject': '家惠',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3條;18顆',
#   'stype': ['每單位量', '有', '問分配', '問剩下']},
#  {'qid': '1MA0141746',
#   'sentence': '哞哞牧場今天生產74625毫升的鮮奶，每375毫升裝成一瓶，共可裝成幾瓶？',
#   'quantities': {'s1': [{'qtyid': 'E5',
#      'quantity': {'value': '74625', 'unit': '毫升', 'entity': '鮮奶'},
#      'verb': '剩下',
#      'subject': '家惠',
#      'object': None}],
#    's2': [{'qtyid': 'E5',
#      'quantity': {'value': '375', 'unit': '毫升', 'entity': '鮮奶'},
#      'verb': '剩下',
#      'subject': '家惠',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '瓶', 'entity': '鮮奶'},
#      'verb': '剩下',
#      'subject': '家惠',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '瓶', 'entity': '鮮奶'},
#      'verb': '剩下',
#      'subject': '家惠',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '199瓶',
#   'stype': ['量變', '每單位量', '問分配']},
#  {'qid': '50665',
#   'sentence': '有600朵百合花，每3朵綁成一束，每間教室用4束布置，可以布置幾間教室？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '600', 'unit': '朵', 'entity': '百合花'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '朵', 'entity': '百合花'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '束', 'entity': '百合花'},
#      'verb': '用',
#      'subject': '教室',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '每', 'unit': '間', 'entity': '教室'},
#      'verb': '用',
#      'subject': '教室',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '4', 'unit': '束', 'entity': '百合花'},
#      'verb': '用',
#      'subject': '教室',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '間', 'entity': '教室'},
#      'verb': '布置',
#      'subject': '教室',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's4': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '50間',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '50666',
#   'sentence': '有84片土司，每2片可以做成4個小三明治，共可以做成幾個小三明治？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '84', 'unit': '片', 'entity': '土司'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '2', 'unit': '片', 'entity': '土司'},
#      'verb': '可以',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '4', 'unit': '個', 'entity': '三明治'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '三明治'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '168個',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '50676',
#   'sentence': '有720顆蘋果，每5顆裝一袋，每9袋裝一箱，共可裝成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '720', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '蘋果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '9', 'unit': '袋', 'entity': '蘋果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '蘋果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '蘋果'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '16箱',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '51738',
#   'sentence': '工廠生產了800個玻璃杯，運送時破了146個，剩下的每6個裝成一盒，可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '800', 'unit': '個', 'entity': '玻璃杯'},
#      'verb': '生產',
#      'subject': '工廠',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '146', 'unit': '個', 'entity': '玻璃杯'},
#      'verb': '運送',
#      'subject': '工廠',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '6', 'unit': '個', 'entity': '玻璃杯'},
#      'verb': '剩下',
#      'subject': '工廠',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '玻璃杯'},
#      'verb': '剩下',
#      'subject': '工廠',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '玻璃杯'},
#      'verb': '裝成',
#      'subject': '工廠',
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '109盒',
#   'stype': ['量變', '量變', '每單位量', '問分配']},
#  {'qid': '50638',
#   'sentence': '有720朵花，每5朵綁成一束，每間教室用6束布置，可以布置幾間教室？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '720', 'unit': '朵', 'entity': '花'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '朵', 'entity': '花'},
#      'verb': '綁',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '束', 'entity': '花'},
#      'verb': '綁',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '6', 'unit': '束', 'entity': '布置'},
#      'verb': '用',
#      'subject': '教室',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '每', 'unit': '間', 'entity': '教室'},
#      'verb': '用',
#      'subject': '教室',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '間', 'entity': '教室'},
#      'verb': '布置',
#      'subject': '教室',
#      'object': None},
#     {'qtyid': 'E7',
#      'quantity': {'value': '每', 'unit': '間', 'entity': '教室'},
#      'verb': '布置',
#      'subject': '教室',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's4': [{'denominator': 'E6', 'numerator': 'E7'}]},
#   'answer': '24間',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '53916',
#   'sentence': '440顆軟糖，每5顆裝成一袋，每8袋裝成一盒，共可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '440', 'unit': '顆', 'entity': '軟糖'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '顆', 'entity': '軟糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '軟糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '8', 'unit': '袋', 'entity': '軟糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '軟糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '軟糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '11盒',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '50685',
#   'sentence': '爸爸採收了720顆草莓，每4顆裝成一盒，每6盒裝成一箱，可以裝成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '720', 'unit': '顆', 'entity': '草莓'},
#      'verb': '採收',
#      'subject': '爸爸',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '顆', 'entity': '草莓'},
#      'verb': '裝成',
#      'subject': '爸爸',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '草莓'},
#      'verb': '裝成',
#      'subject': '爸爸',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '6', 'unit': '盒', 'entity': '草莓'},
#      'verb': '裝成',
#      'subject': '爸爸',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '草莓'},
#      'verb': '裝成',
#      'subject': '爸爸',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '草莓'},
#      'verb': '裝成',
#      'subject': '爸爸',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '30箱',
#   'stype': ['量變', '每單位量', '每單位量', '問分配']},
#  {'qid': '50646',
#   'sentence': '有640顆水蜜桃，在運送時壓壞了100顆，剩下的每5顆裝成一盒，共能裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '640', 'unit': '顆', 'entity': '水蜜桃'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '100', 'unit': '顆', 'entity': '水蜜桃'},
#      'verb': '運送',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '5', 'unit': '顆', 'entity': '水蜜桃'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '水蜜桃'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '水蜜桃'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '108盒',
#   'stype': ['有', '量變', '每單位量', '問分配']},
#  {'qid': '50673',
#   'sentence': '有900顆雞蛋，在運送時壓壞了36顆，剩下的每8顆裝成一盒，共可裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '900', 'unit': '顆', 'entity': '雞蛋'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '36', 'unit': '顆', 'entity': '雞蛋'},
#      'verb': '運送',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '8', 'unit': '顆', 'entity': '雞蛋'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '雞蛋'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '雞蛋'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '108盒',
#   'stype': ['有', '量變', '每單位量', '問分配']},
#  {'qid': '1MA0131359',
#   'sentence': '水果行買了900顆奇異果，早上賣出了44顆，下午老闆將8顆奇異果裝成一個禮盒，可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '900', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '買',
#      'subject': '水果',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '44', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '賣出',
#      'subject': '水果',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '8', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '裝成',
#      'subject': '老闆',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '個', 'entity': '禮盒'},
#      'verb': '裝成',
#      'subject': '老闆',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '禮盒'},
#      'verb': '裝成',
#      'subject': '奇異果',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '107盒',
#   'stype': ['量變', '量變', '每單位量', '問分配']},
#  {'qid': '50737',
#   'sentence': '把50本雜誌平分裝箱，每箱有6本，剩下2本，共平分成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '50', 'unit': '本', 'entity': '雜誌'},
#      'verb': '平分',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '每', 'unit': '箱', 'entity': '雜誌'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '6', 'unit': '本', 'entity': '雜誌'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2', 'unit': '本', 'entity': '雜誌'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '雜誌'},
#      'verb': '平分成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '8箱',
#   'stype': ['有', '每單位量', '剩下', '問分配']},
#  {'qid': '1MA0131328',
#   'sentence': '夏令營原本有875個小朋友參加，後來又有14個小朋友報名，每7人組成一隊，可以組成多少隊？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '875', 'unit': '個', 'entity': '小朋友'},
#      'verb': '有',
#      'subject': '夏令營',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '14', 'unit': '個', 'entity': '小朋友'},
#      'verb': '報名',
#      'subject': '夏令營',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '7', 'unit': None, 'entity': '人'},
#      'verb': '組成',
#      'subject': '夏令營',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '隊', 'entity': '人'},
#      'verb': '組成',
#      'subject': '夏令營',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '隊', 'entity': '人'},
#      'verb': '組成',
#      'subject': '夏令營',
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '127隊',
#   'stype': ['有', '量變', '每單位量', '問分配']},
#  {'qid': '53946',
#   'sentence': '448片小熊餅乾，每7片裝成一袋，每4袋裝成一盒，共可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '448', 'unit': '片', 'entity': '餅乾'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '片', 'entity': '餅乾'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '餅乾'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '4', 'unit': '袋', 'entity': '餅乾'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '餅乾'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '餅乾'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '16盒',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '1MA0131373',
#   'sentence': '112個小朋友參加科學營，後來又有42個小朋友報名，每7人為一組，共可分成多少組？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '112', 'unit': '個', 'entity': '小朋友'},
#      'verb': '加',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '42', 'unit': '個', 'entity': '小朋友'},
#      'verb': '報名',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '7', 'unit': '個', 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '組', 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '多少', 'unit': '組', 'entity': '人'},
#      'verb': '可',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '22組',
#   'stype': ['有', '量變', '每單位量', '問分配']},
#  {'qid': '82272',
#   'sentence': '倉庫裡有4.62公噸的柳丁，每28公斤裝成一箱，共可裝成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4.62', 'unit': '公噸', 'entity': '柳丁'},
#      'verb': '有',
#      'subject': '倉庫',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '28', 'unit': '公斤', 'entity': '柳丁'},
#      'verb': '裝成',
#      'subject': '倉庫',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '柳丁'},
#      'verb': '裝成',
#      'subject': '倉庫',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '柳丁'},
#      'verb': '裝成',
#      'subject': '倉庫',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '165箱',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '31595',
#   'sentence': '用減法算式把做法記下來：35顆葡萄，每7顆裝成一盤，可裝成幾盤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '35', 'unit': '顆', 'entity': '葡萄'},
#      'verb': '用',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '顆', 'entity': '葡萄'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盤', 'entity': '葡萄'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '盤', 'entity': '葡萄'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '5盤',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '30873',
#   'sentence': '用減法算式把做法記下來：16顆巧克力，每4顆裝成一盒，可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '16', 'unit': '顆', 'entity': '巧克力'},
#      'verb': '用',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '顆', 'entity': '巧克力'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '巧克力'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '巧克力'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '4盒',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0162711',
#   'sentence': '把24公斤的糖，每1.6公斤裝成一包，可以裝成多少包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '24', 'unit': '公斤', 'entity': '糖'},
#      'verb': '把',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.6', 'unit': '公斤', 'entity': '糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '包', 'entity': '糖'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '15包',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '103171',
#   'sentence': '將58.26公斤的白米，每0.95公斤裝成一袋，可裝成幾袋？剩下幾公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '58.26', 'unit': '公斤', 'entity': '白米'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.95', 'unit': '公斤', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '袋', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '公斤', 'entity': '白米'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '61袋;0.31公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '111308',
#   'sentence': '一袋紅豆重21+(1/3)公斤。玲玲有3袋的紅豆，每1+(19/45)公斤裝一包，相當於裝幾包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '21+(1/3)', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '1+(19/45)', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '包', 'entity': '紅豆'},
#      'verb': '相當於',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '45包',
#   'stype': ['每單位量', '有', '每單位量', '問分配']},
#  {'qid': '1MA0162717',
#   'sentence': '把2.75公升的果汁，每0.25公升裝成一杯，可以裝成多少杯？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '2.75', 'unit': '公升', 'entity': '果汁'},
#      'verb': '把',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.25', 'unit': '公升', 'entity': '果汁'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '杯', 'entity': '果汁'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '杯', 'entity': '果汁'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '11杯',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0160767',
#   'sentence': '袋子裡有72枝棒棒糖。每12枝裝一袋，一共可裝成多少袋？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '72', 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': '有',
#      'subject': '袋子',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '12', 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': '裝',
#      'subject': '袋子',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '棒棒糖'},
#      'verb': '裝',
#      'subject': '袋子',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': None, 'entity': '棒棒糖'},
#      'verb': '裝成',
#      'subject': '袋子',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '袋', 'entity': '棒棒糖'},
#      'verb': '裝成',
#      'subject': '袋子',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '6袋',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0162724',
#   'sentence': '一袋13.7公斤的紅豆，每2.3公斤裝一包，可以裝成多少包？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '13.7', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '紅豆'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '2.3', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '包', 'entity': '紅豆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '5包;2.2公斤',
#   'stype': ['每單位量', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160548',
#   'sentence': '58.9公斤的白米，每3.26公斤裝成一袋，可以裝成多少袋？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '58.9', 'unit': '公斤', 'entity': '白米'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3.26', 'unit': '公斤', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '袋', 'entity': '白米'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '白米'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '18袋;0.22公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0162694',
#   'sentence': '一袋麵粉有2公斤，每0.5公斤分裝成1小包，共可裝滿多少包？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '麵粉'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '公斤', 'entity': '麵粉'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '0.5', 'unit': '公斤', 'entity': '麵粉'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '1', 'unit': '包', 'entity': '麵粉'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '包', 'entity': '麵粉'},
#      'verb': '裝滿',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '麵粉'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '4包;0公斤',
#   'stype': ['每單位量', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160561',
#   'sentence': '一桶果汁有126.8公升，分裝在每瓶容量2.75公升的瓶子裡，可以裝成幾瓶？還剩下多少公升？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '桶', 'entity': '果汁'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '126.8', 'unit': '公升', 'entity': '果汁'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '每', 'unit': '瓶', 'entity': '容量'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '2.75', 'unit': '公升', 'entity': '瓶子'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '瓶', 'entity': '瓶子'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '多少', 'unit': '公升', 'entity': '瓶子'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '46瓶;0.3公升',
#   'stype': ['每單位量', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160551',
#   'sentence': '有25.7公斤的橘子，每3.2公斤裝一箱，可以裝滿幾箱？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '25.7', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3.2', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '橘子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '橘子'},
#      'verb': '裝滿',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '8箱;0.1公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160550',
#   'sentence': '26.7公斤的綠豆，每2.38公斤裝成一袋，可以裝成多少袋？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '26.7', 'unit': '公斤', 'entity': '綠豆'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2.38', 'unit': '公斤', 'entity': '綠豆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '綠豆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '袋', 'entity': '綠豆'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '綠豆'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '11袋;0.52公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '111344',
#   'sentence': '將7+(1/3)公斤的紫米、2+(1/3)公斤的薏仁、3+(1/3)公斤的燕麥混合，每1+(1/12)公斤裝成一包，可裝成幾包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7+(1/3)', 'unit': '公斤', 'entity': '紫米'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '2+(1/3)', 'unit': '公斤', 'entity': '薏仁'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None}],
#    's2': [{'qtyid': 'E4',
#      'quantity': {'value': '1+(1/12)', 'unit': '公斤', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None}],
#    's3': [{'qtyid': 'E7',
#      'quantity': {'value': '幾', 'unit': '包', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E8',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '12包',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0160575',
#   'sentence': '做一個中國結需用掉25.5公分長的繩子，2.5公尺長的繩子，最多可以完成幾個中國結？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '25.5', 'unit': '公分', 'entity': '繩子'},
#      'verb': '需用',
#      'subject': '中國結',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '個', 'entity': '中國結'},
#      'verb': '需用',
#      'subject': '中國結',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '2.5', 'unit': '公尺', 'entity': '繩子'},
#      'verb': None,
#      'subject': '中國結',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '個', 'entity': '中國結'},
#      'verb': None,
#      'subject': '中國結',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '中國結'},
#      'verb': '可以',
#      'subject': '中國結',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '9個',
#   'stype': ['每單位量', '有', '問分配']},
#  {'qid': '1MA0162716',
#   'sentence': '把4.8公斤的糖果，每0.6公斤裝一包，可以裝成多少包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4.8', 'unit': '公斤', 'entity': '糖果'},
#      'verb': '把',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.6', 'unit': '公斤', 'entity': '糖果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '糖果'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '包', 'entity': '糖果'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '8包',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '100534',
#   'sentence': '一袋芋圓重14.81公斤，做一鍋甜湯需要0.21公斤的芋圓，這袋芋圓最多可以做幾鍋甜湯？剩下幾公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '圓'},
#      'verb': '重',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '14.81', 'unit': '公斤', 'entity': '圓'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '鍋', 'entity': '甜湯'},
#      'verb': '做',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '0.21', 'unit': '公斤', 'entity': '圓'},
#      'verb': '做',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '鍋', 'entity': '甜湯'},
#      'verb': '做',
#      'subject': '這',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '公斤', 'entity': '甜湯'},
#      'verb': '剩下',
#      'subject': '圓',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '70鍋;0.11公斤',
#   'stype': ['每單位量', '每單位量', '問分配', '問剩下']},
#  {'qid': '100525',
#   'sentence': '200公尺彩帶，用去100.64公尺後，把剩下的彩帶每3.26公尺包裝一份禮物，最多可以包裝幾份禮物？剩下幾公尺？',
#   'quantities': {'s1': [{'qtyid': 'E2',
#      'quantity': {'value': '200', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '100.64', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '用去',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '3.26', 'unit': '公尺', 'entity': '包裝'},
#      'verb': '把',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '份', 'entity': '禮物'},
#      'verb': '把',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '份', 'entity': '禮物'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's5': [{'qtyid': 'E7',
#      'quantity': {'value': '幾', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '30份;1.56公尺',
#   'stype': ['有', '量變', '每單位量', '問分配', '問剩下']},
#  {'qid': '101291',
#   'sentence': '有一桶25公升的青草茶，每個杯子可以裝0.34公升，最多可以裝成幾杯（須為整數）？還剩下幾公升的青草茶？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '25', 'unit': '公升', 'entity': '青草茶'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '桶', 'entity': '青草茶'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '每', 'unit': '個', 'entity': '杯子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '0.34', 'unit': '公升', 'entity': '杯子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '杯', 'entity': '杯子'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '公升', 'entity': '青草茶'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '73杯;0.18公升',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160768',
#   'sentence': '瓶子裡有108顆巧克力球。每18顆裝一包，一共可裝成多少包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '108', 'unit': '顆', 'entity': '球'},
#      'verb': '有',
#      'subject': '瓶子',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '18', 'unit': '顆', 'entity': '球'},
#      'verb': '裝',
#      'subject': '瓶子',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '球'},
#      'verb': '裝',
#      'subject': '瓶子',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': None, 'entity': '球'},
#      'verb': '裝成',
#      'subject': '瓶子',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '包', 'entity': '球'},
#      'verb': '裝成',
#      'subject': '瓶子',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '6包',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0160552',
#   'sentence': '有38.75公斤的橘子，每4.4公斤裝一箱，可以裝滿幾箱？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '38.75', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4.4', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '橘子'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '橘子'},
#      'verb': '裝滿',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '橘子'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '8箱;3.55公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160553',
#   'sentence': '一條長5公尺的緞帶，每0.45公尺剪成一段，可以剪成幾段？還剩下多少公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '5', 'unit': '公尺', 'entity': '緞帶'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.45', 'unit': '公尺', 'entity': '緞帶'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '段', 'entity': '緞帶'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '段', 'entity': '緞帶'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公尺', 'entity': '緞帶'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '11段;0.05公尺',
#   'stype': ['每單位量', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0160525',
#   'sentence': '一大桶果汁有19.2公升，每1.2公升分裝成一小桶，共可以分裝成幾小桶？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '大桶', 'entity': '果汁'},
#      'verb': '有',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '19.2', 'unit': '公升', 'entity': '果汁'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '1.2', 'unit': '公升', 'entity': '果汁'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '小桶', 'entity': '果汁'},
#      'verb': '分裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
# ...
#      'quantity': {'value': '一', 'unit': '排', 'entity': '椅子'},
#      'verb': None,
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '排椅子'},
#      'verb': '可以',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '3排',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '40940',
#   'sentence': '寫出除法算式做做看：14個杯子，2個裝一盒，可裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '14', 'unit': '個', 'entity': '杯子'},
#      'verb': '做做',
#      'subject': '算式',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '個', 'entity': '杯子'},
#      'verb': '裝',
#      'subject': '算式',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '杯子'},
#      'verb': '裝',
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '杯子'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '7盒',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '40949',
#   'sentence': '寫出除法算式做做看：15顆番茄，3顆串成一串，可以串成幾串？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '15', 'unit': '顆', 'entity': '番茄'},
#      'verb': '做做',
#      'subject': '算式',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '顆', 'entity': '番茄'},
#      'verb': None,
#      'subject': '算式',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '串', 'entity': '番茄'},
#      'verb': None,
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '串', 'entity': '番茄'},
#      'verb': '可以',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '5串',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0131263',
#   'sentence': '小惠的媽媽做了64個飯糰，4個裝一盒，可以裝成多少盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '64', 'unit': '個', 'entity': '飯糰'},
#      'verb': '做',
#      'subject': '小惠',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '個', 'entity': '飯糰'},
#      'verb': '裝',
#      'subject': '媽媽',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '飯糰'},
#      'verb': '裝',
#      'subject': '媽媽',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '多少', 'unit': '盒', 'entity': '飯糰'},
#      'verb': '裝成',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '16盒',
#   'stype': ['量變', '每單位量', '問分配']},
#  {'qid': '1MA0131025',
#   'sentence': '有22個花片，每3個分成一堆，可以分成幾堆？還剩下幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '22', 'unit': '個', 'entity': '花片'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '個', 'entity': '花片'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '堆', 'entity': '花片'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '堆', 'entity': '花片'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '花片'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '7堆;1個',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '40965',
#   'sentence': '寫出除法算式做做看：18顆球，3顆裝成一袋，可以裝成幾袋？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '18', 'unit': '顆', 'entity': '球'},
#      'verb': '做做',
#      'subject': '算式',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '顆', 'entity': '球'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '球'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '袋', 'entity': '球'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '6袋',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0130982',
#   'sentence': '有30個香水蠟燭，6個裝一盒，可以裝成幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '30', 'unit': '個', 'entity': '蠟燭'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '6', 'unit': '個', 'entity': '蠟燭'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盒', 'entity': '蠟燭'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '蠟燭'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '5盒',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '41072',
#   'sentence': '寫出算式做做看：玻璃珠70顆，每10顆裝一瓶，可以裝成多少瓶？',
#   'quantities': {'s1': [{'qtyid': 'E2',
#      'quantity': {'value': '70', 'unit': '顆', 'entity': '玻璃珠'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '10', 'unit': '顆', 'entity': '玻璃珠'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '瓶', 'entity': '玻璃珠'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '多少', 'unit': '瓶', 'entity': '玻璃珠'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '7瓶',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '41005',
#   'sentence': '20個毽子，平分給5組小朋友，每組小朋友分到幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '20', 'unit': '個', 'entity': '毽子'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '組', 'entity': '小朋友'},
#      'verb': '平分給',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '每', 'unit': '組', 'entity': '小朋友'},
#      'verb': '分到',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '小朋友'},
#      'verb': '分到',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '4個',
#   'stype': ['有', '平分', '問分配']},
#  {'qid': '41083',
#   'sentence': '寫出算式做做看：14公斤的鹽，每2公斤裝成一袋，可以裝成幾袋？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '14', 'unit': '公斤', 'entity': '鹽'},
#      'verb': '做做',
#      'subject': '算式',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '公斤', 'entity': '鹽'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '鹽'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '袋', 'entity': '鹽'},
#      'verb': '裝成',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '7袋',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '41044',
#   'sentence': '40個扯鈴，平分給8組小朋友，每組小朋友分到幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '40', 'unit': '個', 'entity': '扯鈴'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '8', 'unit': '組', 'entity': '小朋友'},
#      'verb': '平分給',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '每', 'unit': '組', 'entity': '小朋友'},
#      'verb': '分到',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '小朋友'},
#      'verb': '分到',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '5個',
#   'stype': ['有', '平分', '問分配']},
#  {'qid': '40978',
#   'sentence': '寫出算式做做看：8個小朋友跳舞，每2個人分成一組，可以分成幾組？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '個', 'entity': '小朋友'},
#      'verb': '做做',
#      'subject': '算式',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '個', 'entity': '人'},
#      'verb': None,
#      'subject': '算式',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '組', 'entity': '人'},
#      'verb': None,
#      'subject': '算式',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '組', 'entity': '人'},
#      'verb': '可以',
#      'subject': '算式',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '4組',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '53906',
#   'sentence': '142個甜甜圈，每4個裝成一袋，可裝成幾袋？剩下幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '142', 'unit': '個', 'entity': '甜甜圈'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '個', 'entity': '甜甜圈'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '甜甜圈'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '袋', 'entity': '甜甜圈'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '甜甜圈'},
#      'verb': '剩下',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '35袋;2個',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0131110',
#   'sentence': '鉛筆一枝賣5元，美美帶了48元，最多可以買幾枝鉛筆？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '48', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '美美',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '9枝',
#   'stype': ['每單位量', '量變', '問分配']},
#  {'qid': '1MA0131289',
#   'sentence': '一個盤子可以裝9顆水餃，媽媽煮了95顆水餃，可以裝滿幾個盤子？還剩下幾顆水餃？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '9', 'unit': '顆', 'entity': '水餃'},
#      'verb': '裝',
#      'subject': '盤子',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '一', 'unit': '個', 'entity': '盤子'},
#      'verb': '裝',
#      'subject': '盤子',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '95', 'unit': '顆', 'entity': '水餃'},
#      'verb': '煮',
#      'subject': '媽媽',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '盤子'},
#      'verb': '裝滿',
#      'subject': '媽媽',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '顆', 'entity': '水餃'},
#      'verb': '剩下',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '10個;5顆',
#   'stype': ['每單位量', '量變', '問分配', '問剩下']},
#  {'qid': '1MA0131318',
#   'sentence': '有954顆水餃，每9顆裝一盤，一共可以裝成幾盤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '954', 'unit': '顆', 'entity': '水餃'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '9', 'unit': '顆', 'entity': '水餃'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '盤', 'entity': '水餃'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': None, 'entity': '水餃'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '盤', 'entity': '水餃'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '106盤',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0151525',
#   'sentence': '1.8公噸的香菇，每200公斤裝成1袋，可以裝成幾袋？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '1.8', 'unit': '公噸', 'entity': '香菇'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '200', 'unit': '公斤', 'entity': '香菇'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '1', 'unit': '袋', 'entity': '香菇'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '袋', 'entity': '香菇'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '9袋',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '84150',
#   'sentence': '4500顆巧克力，每15顆裝成一包，每12包裝成一箱，共可裝成幾箱？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4500', 'unit': '顆', 'entity': '巧克力'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '15', 'unit': '顆', 'entity': '巧克力'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '巧克力'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '12', 'unit': None, 'entity': '包裝'},
#      'verb': '成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '一', 'unit': '箱', 'entity': '包裝'},
#      'verb': '成',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '幾', 'unit': '箱', 'entity': '包裝'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '25箱',
#   'stype': ['有', '每單位量', '每單位量', '問分配']},
#  {'qid': '1MA0151559',
#   'sentence': '一袋糖果重3公噸500公斤，每50公斤裝成一包，全部可以裝成幾包糖果？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '袋', 'entity': '糖果'},
#      'verb': '重',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '3.5', 'unit': '公噸', 'entity': '糖果'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '50', 'unit': '公斤', 'entity': '糖果'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '一', 'unit': '包', 'entity': '糖果'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '包', 'entity': '糖果'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '70包',
#   'stype': ['每單位量', '每單位量', '問分配']}]

# %%
correct_case = []
wrong_case = []
wrong = 0
correct = 0
unsolve  = 0

for i in range(0, len(extracted_data)):
    try:
        if solver.solve(extracted_data[i]):
            correct+=1
            correct_case.append((extracted_data[i]))
        else:
            wrong_case.append(extracted_data[i])
            wrong+=1

    except:
        wrong_case.append((extracted_data[i]))
        wrong+=1

print(f"Problems:{len(extracted_data)}, Correct:{correct}, Wrong:{wrong}, Accuracy:{correct/len(extracted_data)} ")
# Out:
# {'Formula': '845 / 13.0 = 65.0', 'My Answer': '65.0束'}
# {'Formula': '512 / 32.0 = 16.0', 'My Answer': '16.0枝'}
# {'Formula': '9000 / 110.0 = 81.0...90.0', 'My Answer': '81.0箱;90.0顆'}
# {'Formula': '88 / 16.0 = 5.0...8.0', 'My Answer': '5.0束;8.0朵'}
# {'Formula': '775000 / 1800.0 = 430.0...1000.0', 'My Answer': '430.0箱;1000.0枝'}
# {'Formula': '99 / 19.0 = 5.0...4.0', 'My Answer': '5.0簍;4.0個'}
# {'Formula': '36572 / 100.0 = 365.0...72.0', 'My Answer': '365.0箱;72.0架'}
# {'Formula': '(120 / 6.0) / 5.0 = 4.0', 'My Answer': '4.0箱'}
# {'Formula': '99 / 27.0 = 3.0...18.0', 'My Answer': '3.0條;18.0顆'}
# {'Formula': '74625 / 375.0 = 199.0', 'My Answer': '199.0瓶'}
# {'Formula': '(600 / 3.0) / 4.0 = 50.0', 'My Answer': '50.0間'}
# {'Formula': '84 / 0.5 = 168.0', 'My Answer': '168.0個'}
# {'Formula': '(720 / 5.0) / 9.0 = 16.0', 'My Answer': '16.0箱'}
# {'Formula': '(800 - 146) / 6.0 = 109.0', 'My Answer': '109.0盒'}
# {'Formula': '(720 / 5.0) / 6.0 = 24.0', 'My Answer': '24.0間'}
# {'Formula': '(440 / 5.0) / 8.0 = 11.0', 'My Answer': '11.0盒'}
# {'Formula': '(720 / 4.0) / 6.0 = 30.0', 'My Answer': '30.0箱'}
# {'Formula': '(640 - 100) / 5.0 = 108.0', 'My Answer': '108.0盒'}
# {'Formula': '(900 - 36) / 8.0 = 108.0', 'My Answer': '108.0盒'}
# {'Formula': '(900 - 44) / 8.0 = 107.0', 'My Answer': '107.0盒'}
# {'Formula': '(50 - 2) / 6.0 = 8.0', 'My Answer': '8.0箱'}
# {'Formula': '(875 + 14) / 7.0 = 127.0', 'My Answer': '127.0隊'}
# {'Formula': '(448 / 7.0) / 4.0 = 16.0', 'My Answer': '16.0盒'}
# {'Formula': '(112 + 42) / 7.0 = 22.0', 'My Answer': '22.0組'}
# {'Formula': '4620.0 / 28.0 = 165.0', 'My Answer': '165.0箱'}
# {'Formula': '35 / 7.0 = 5.0', 'My Answer': '5.0盤'}
# {'Formula': '16 / 4.0 = 4.0', 'My Answer': '4.0盒'}
# {'Formula': '24 / 1.6 = 15.0', 'My Answer': '15.0包'}
# {'Formula': '58.26 / 0.95 = 61.0...0.31', 'My Answer': '61.0袋;0.31公斤'}
# {'Formula': '2.75 / 0.25 = 11.0', 'My Answer': '11.0杯'}
# {'Formula': '72 / 12.0 = 6.0', 'My Answer': '6.0袋'}
# {'Formula': '13.7 / 2.3 = 5.0...2.2', 'My Answer': '5.0包;2.2公斤'}
# {'Formula': '58.9 / 3.26 = 18.0...0.22', 'My Answer': '18.0袋;0.22公斤'}
# {'Formula': '2 / 0.5 = 4.0...0.0', 'My Answer': '4.0包;0.0公斤'}
# {'Formula': '126.8 / 2.75 = 46.0...0.3', 'My Answer': '46.0瓶;0.3公升'}
# {'Formula': '25.7 / 3.2 = 8.0...0.1', 'My Answer': '8.0箱;0.1公斤'}
# {'Formula': '26.7 / 2.38 = 11.0...0.52', 'My Answer': '11.0袋;0.52公斤'}
# {'Formula': '250.0 / 25.5 = 9.8', 'My Answer': '9.8個'}
# {'Formula': '4.8 / 0.6 = 8.0', 'My Answer': '8.0包'}
# {'Formula': '14.81 / 0.21 = 70.0...0.11', 'My Answer': '70.0鍋;0.11公斤'}
# {'Formula': '(200 - 100.64) / 3.26 = 30.0...1.56', 'My Answer': '30.0份;1.56公尺'}
# {'Formula': '25 / 0.34 = 73.0...0.18', 'My Answer': '73.0杯;0.18公升'}
# {'Formula': '108 / 18.0 = 6.0', 'My Answer': '6.0包'}
# {'Formula': '38.75 / 4.4 = 8.0...3.55', 'My Answer': '8.0箱;3.55公斤'}
# Not enough variables found for sentence s1. Expected 2, found 1.
# {'Formula': '5 / 0.45 = 11.0...0.05', 'My Answer': '11.0段;0.05公尺'}
# {'Formula': '19.2 / 1.2 = 16.0', 'My Answer': '16.0小桶'}
# {'Formula': '27 / 1.9 = 14.0...0.4', 'My Answer': '14.0瓶;0.4公升'}
# {'Formula': '18.7 / 0.3 = 62.0...0.1', 'My Answer': '62.0杯;0.1公升'}
# {'Formula': '25 / 0.54 = 46.0...0.16', 'My Answer': '46.0瓶;0.16公升'}
# {'Formula': '18 / 0.36 = 50.0', 'My Answer': '50.0包'}
# {'Formula': '256 / 16.0 = 16.0', 'My Answer': '16.0個'}
# {'Formula': '100 / 3.5 = 28.0...2.0', 'My Answer': '28.0張;2.0元'}
# {'Formula': '435 / 29.0 = 15.0', 'My Answer': '15.0杯'}
# {'Formula': '37 / 1.48 = 25.0', 'My Answer': '25.0段'}
# {'Formula': '15 / 1.05 = 14.0...0.3', 'My Answer': '14.0段;0.3公尺'}
# {'Formula': '40.95 / 3.15 = 13.0', 'My Answer': '13.0袋'}
# {'Formula': '18 / 2.3 = 7.0...1.9', 'My Answer': '7.0包;1.9公斤'}
# {'Formula': '123.36 / 3.8 = 32.0...1.76', 'My Answer': '32.0袋;1.76公斤'}
# {'Formula': '3 / 0.2 = 15.0', 'My Answer': '15.0杯'}
# {'Formula': '29.8 / 0.64 = 46.56', 'My Answer': '46.56個'}
# {'Formula': '24.6 / 1.6 = 15.0...0.6', 'My Answer': '15.0個;0.6公尺'}
# {'Formula': '(50 - 11.12) / 1.08 = 36.0', 'My Answer': '36.0段'}
# {'Formula': '69.9 / 1.625 = 43.0...0.03', 'My Answer': '43.0瓶;0.03公升'}
# {'Formula': '1.12 / 0.16 = 7.0', 'My Answer': '7.0包'}
# {'Formula': '675 / 45.0 = 15.0', 'My Answer': '15.0盒'}
# {'Formula': '42 / 6.0 = 7.0', 'My Answer': '7.0串'}
# {'Formula': '72 / 8.0 = 9.0', 'My Answer': '9.0圈'}
# {'Formula': '48 / 12.0 = 4.0', 'My Answer': '4.0隊'}
# {'Formula': '64 / 8.0 = 8.0', 'My Answer': '8.0袋'}
# {'Formula': '30 / 6.0 = 5.0', 'My Answer': '5.0盒'}
# {'Formula': '30 / 6.0 = 5.0', 'My Answer': '5.0盤'}
# {'Formula': '81 / 9.0 = 9.0', 'My Answer': '9.0組'}
# {'Formula': '56 / 8.0 = 7.0', 'My Answer': '7.0段'}
# {'Formula': '60 / 10.0 = 6.0', 'My Answer': '6.0盒'}
# {'Formula': '70 / 10.0 = 7.0', 'My Answer': '7.0束'}
# {'Formula': '5 / 0.125 = 40.0', 'My Answer': '40.0片'}
# {'Formula': '25 / 5.0 = 5.0', 'My Answer': '5.0串'}
# {'Formula': '42 / 6.0 = 7.0', 'My Answer': '7.0袋'}
# {'Formula': '40 / 8.0 = 5.0', 'My Answer': '5.0包'}
# {'Formula': '21 / 3.0 = 7.0', 'My Answer': '7.0包'}
# {'Formula': '27 / 3.0 = 9.0', 'My Answer': '9.0串'}
# {'Formula': '49 / 7.0 = 7.0', 'My Answer': '7.0排'}
# {'Formula': '16 / 4.0 = 4.0', 'My Answer': '4.0串'}
# {'Formula': '49 / 7.0 = 7.0', 'My Answer': '7.0袋'}
# {'Formula': '45 / 5.0 = 9.0', 'My Answer': '9.0盤'}
# {'Formula': '36 / 9.0 = 4.0', 'My Answer': '4.0盒'}
# {'Formula': '50 / 10.0 = 5.0', 'My Answer': '5.0束'}
# {'Formula': '60000.0 / 150.0 = 400.0', 'My Answer': '400.0杯'}
# {'Formula': '20 / 10.0 = 2.0', 'My Answer': '2.0瓶'}
# {'Formula': '42 / 6.0 = 7.0', 'My Answer': '7.0段'}
# {'Formula': '16 / 2.0 = 8.0', 'My Answer': '8.0雙'}
# {'Formula': '24 / 6.0 = 4.0', 'My Answer': '4.0組'}
# {'Formula': '35 / 7.0 = 5.0', 'My Answer': '5.0隊'}
# {'Formula': '56 / 7.0 = 8.0', 'My Answer': '8.0包'}
# {'Formula': '81 / 9.0 = 9.0', 'My Answer': '9.0袋'}
# {'Formula': '42 / 6.0 = 7.0', 'My Answer': '7.0列'}
# {'Formula': '30 / 6.0 = 5.0', 'My Answer': '5.0盤'}
# {'Formula': '64 / 8.0 = 8.0', 'My Answer': '8.0頁'}
# {'Formula': '30 / 3.0 = 10.0...0.0', 'My Answer': '10.0盤;0.0顆'}
# {'Formula': '56 / 7.0 = 8.0', 'My Answer': '8.0None'}
# {'Formula': '60 / 10.0 = 6.0', 'My Answer': '6.0束'}
# {'Formula': '56 / 7.0 = 8.0', 'My Answer': '8.0盤'}
# {'Formula': '45 / 9.0 = 5.0', 'My Answer': '5.0顆'}
# {'Formula': '48 / 6.0 = 8.0', 'My Answer': '8.0串'}
# {'Formula': '56 / 7.0 = 8.0', 'My Answer': '8.0盒'}
# {'Formula': '32 / 8.0 = 4.0', 'My Answer': '4.0束'}
# {'Formula': '56 / 8.0 = 7.0', 'My Answer': '7.0碗'}
# {'Formula': '36 / 9.0 = 4.0', 'My Answer': '4.0堆'}
# {'Formula': '32 / 4.0 = 8.0', 'My Answer': '8.0瓶'}
# {'Formula': '48 / 8.0 = 6.0', 'My Answer': '6.0組'}
# {'Formula': '48 / 8.0 = 6.0', 'My Answer': '6.0箱'}
# {'Formula': '45 / 9.0 = 5.0', 'My Answer': '5.0盒'}
# {'Formula': '48 / 8.0 = 6.0', 'My Answer': '6.0袋'}
# {'Formula': '48 / 8.0 = 6.0', 'My Answer': '6.0包'}
# {'Formula': '80 / 10.0 = 8.0', 'My Answer': '8.0盒'}
# {'Formula': '48 / 8.0 = 6.0', 'My Answer': '6.0排'}
# {'Formula': '32 / 4.0 = 8.0', 'My Answer': '8.0組'}
# {'Formula': '28 / 4.0 = 7.0', 'My Answer': '7.0組'}
# {'Formula': '18 / 3.0 = 6.0', 'My Answer': '6.0袋'}
# {'Formula': '72 / 9.0 = 8.0', 'My Answer': '8.0袋'}
# {'Formula': '56 / 7.0 = 8.0', 'My Answer': '8.0包'}
# {'Formula': '30 / 10.0 = 3.0', 'My Answer': '3.0包'}
# {'Formula': '50 / 10.0 = 5.0', 'My Answer': '5.0盒'}
# {'Formula': '49 / 7.0 = 7.0', 'My Answer': '7.0盒'}
# {'Formula': '16 / 2.0 = 8.0', 'My Answer': '8.0包'}
# {'Formula': '35 / 5.0 = 7.0', 'My Answer': '7.0排'}
# {'Formula': '32 / 4.0 = 8.0', 'My Answer': '8.0盤'}
# {'Formula': '35 / 7.0 = 5.0', 'My Answer': '5.0袋'}
# {'Formula': '27 / 9.0 = 3.0', 'My Answer': '3.0組'}
# {'Formula': '56 / 8.0 = 7.0', 'My Answer': '7.0袋'}
# {'Formula': '63 / 7.0 = 9.0', 'My Answer': '9.0袋'}
# {'Formula': '32 / 4.0 = 8.0', 'My Answer': '8.0串'}
# {'Formula': '12 / 2.0 = 6.0', 'My Answer': '6.0袋'}
# {'Formula': '36 / 6.0 = 6.0', 'My Answer': '6.0條'}
# {'Formula': '21 / 7.0 = 3.0', 'My Answer': '3.0包'}
# {'Formula': '87 / 10.0 = 8.0...7.0', 'My Answer': '8.0包;7.0公斤'}
# {'Formula': '(3500 - 43) / 35.0 = 98.77', 'My Answer': '98.77盒'}
# {'Formula': '3000 / 26.0 = 115.0...10.0', 'My Answer': '115.0段;10.0公分'}
# {'Formula': '34000.0 / 400.0 = 85.0', 'My Answer': '85.0盒'}
# {'Formula': '18000.0 / 350.0 = 51.43', 'My Answer': '51.43袋'}
# {'Formula': '56 / 8.0 = 7.0', 'My Answer': '7.0盒'}
# {'Formula': '98 / 2.0 = 49.0', 'My Answer': '49.0包'}
# {'Formula': '15 / 3.0 = 5.0', 'My Answer': '5.0杯'}
# {'Formula': '16 / 2.0 = 8.0', 'My Answer': '8.0雙'}
# {'Formula': '(12 / 1.0) / 2.0 = 6.0', 'My Answer': '6.0個'}
# {'Formula': '470 / 9.0 = 52.0...2.0', 'My Answer': '52.0盒;2.0顆'}
# {'Formula': '18 / 2.0 = 9.0', 'My Answer': '9.0盒'}
# {'Formula': '12 / 2.0 = 6.0', 'My Answer': '6.0盒'}
# {'Formula': '15 / 5.0 = 3.0', 'My Answer': '3.0None'}
# {'Formula': '14 / 2.0 = 7.0', 'My Answer': '7.0盒'}
# {'Formula': '15 / 3.0 = 5.0', 'My Answer': '5.0串'}
# {'Formula': '64 / 4.0 = 16.0', 'My Answer': '16.0盒'}
# {'Formula': '22 / 3.0 = 7.0...1.0', 'My Answer': '7.0堆;1.0個'}
# {'Formula': '18 / 3.0 = 6.0', 'My Answer': '6.0袋'}
# {'Formula': '30 / 6.0 = 5.0', 'My Answer': '5.0盒'}
# {'Formula': '70 / 10.0 = 7.0', 'My Answer': '7.0瓶'}
# {'Formula': '20 / 5.0 = 4.0', 'My Answer': '4.0個'}
# {'Formula': '14 / 2.0 = 7.0', 'My Answer': '7.0袋'}
# {'Formula': '40 / 8.0 = 5.0', 'My Answer': '5.0個'}
# {'Formula': '8 / 2.0 = 4.0', 'My Answer': '4.0組'}
# {'Formula': '142 / 4.0 = 35.0...2.0', 'My Answer': '35.0袋;2.0個'}
# {'Formula': '48 / 5.0 = 9.6', 'My Answer': '9.6枝'}
# {'Formula': '95 / 9.0 = 10.0...5.0', 'My Answer': '10.0個;5.0顆'}
# {'Formula': '954 / 9.0 = 106.0', 'My Answer': '106.0盤'}
# {'Formula': '1800.0 / 200.0 = 9.0', 'My Answer': '9.0袋'}
# {'Formula': '(4500 / 15.0) / 12.0 = 25.0', 'My Answer': '25.0箱'}
# {'Formula': '3500.0 / 50.0 = 70.0', 'My Answer': '70.0包'}
# Problems:170, Correct:163, Wrong:7, Accuracy:0.9588235294117647

# %%
wrong_case
# Out:
# [{'qid': '111308',
#   'sentence': '一袋紅豆重21+(1/3)公斤。玲玲有3袋的紅豆，每1+(19/45)公斤裝一包，相當於裝幾包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '袋', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '21+(1/3)', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '1+(19/45)', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '包', 'entity': '紅豆'},
#      'verb': '相當於',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '45包',
#   'stype': ['每單位量', '有', '每單位量', '問分配']},
#  {'qid': '111344',
#   'sentence': '將7+(1/3)公斤的紫米、2+(1/3)公斤的薏仁、3+(1/3)公斤的燕麥混合，每1+(1/12)公斤裝成一包，可裝成幾包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7+(1/3)', 'unit': '公斤', 'entity': '紫米'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '2+(1/3)', 'unit': '公斤', 'entity': '薏仁'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '混合',
#      'subject': '薏仁',
#      'object': None}],
#    's2': [{'qtyid': 'E4',
#      'quantity': {'value': '1+(1/12)', 'unit': '公斤', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None}],
#    's3': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '包', 'entity': '紫米'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None},
#     {'qtyid': 'E8',
#      'quantity': {'value': '3+(1/3)', 'unit': '公斤', 'entity': '燕麥'},
#      'verb': '裝成',
#      'subject': '燕麥',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '12包',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0160575',
#   'sentence': '做一個中國結需用掉25.5公分長的繩子，2.5公尺長的繩子，最多可以完成幾個中國結？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '25.5', 'unit': '公分', 'entity': '繩子'},
#      'verb': '需用',
#      'subject': '中國結',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '中國結'},
#      'verb': '需用',
#      'subject': '中國結',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '2.5', 'unit': '公尺', 'entity': '繩子'},
#      'verb': None,
#      'subject': '中國結',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '中國結'},
#      'verb': None,
#      'subject': '中國結',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '個', 'entity': '中國結'},
#      'verb': '可以',
#      'subject': '中國結',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '9個',
#   'stype': ['每單位量', '有', '問分配']},
#  {'qid': '111309',
#   'sentence': '一袋紅豆重9+(1/2)公斤。玲玲有3袋的紅豆，每3/4公斤裝一包，相當於裝幾包？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '袋', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '9+(1/2)', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '袋', 'entity': '紅豆'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '3/4', 'unit': '公斤', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '紅豆'},
#      'verb': '裝',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '包', 'entity': '紅豆'},
#      'verb': '相當於',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '38包',
#   'stype': ['每單位量', '有', '每單位量', '問分配']},
#  {'qid': '102789',
#   'sentence': '有29.8公升的果汁，每0.64公升裝成一瓶，共需要幾個瓶子才能裝完？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '29.8', 'unit': '公升', 'entity': '果汁'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.64', 'unit': '公升', 'entity': '果汁'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '瓶子'},
#      'verb': '裝成',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '個', 'entity': '瓶子'},
#      'verb': '裝',
#      'subject': '瓶子',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '47個',
#   'stype': ['有', '每單位量', '問分配']},
#  {'qid': '1MA0141116',
#   'sentence': '雜貨店老闆買進了87公斤的綠豆和46公斤的薏仁，混合後每10公斤裝成一包，可以裝滿幾包？還剩下多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '87', 'unit': '公斤', 'entity': '綠豆'},
#      'verb': '買進',
#      'subject': '老闆',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '46', 'unit': '公斤', 'entity': '薏仁'},
#      'verb': '買進',
#      'subject': '老闆',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '10', 'unit': '公斤', 'entity': '薏仁'},
#      'verb': '混合',
#      'subject': '老闆',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '薏仁'},
#      'verb': '混合',
#      'subject': '老闆',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '包', 'entity': '薏仁'},
#      'verb': '裝滿',
#      'subject': '老闆',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '公斤', 'entity': '薏仁'},
#      'verb': '剩下',
#      'subject': '老闆',
#      'object': None}]},
#   'unitmaps': {'s2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '13包;3公斤',
#   'stype': ['有', '每單位量', '問分配', '問剩下']},
#  {'qid': '1MA0131110',
#   'sentence': '鉛筆一枝賣5元，美美帶了48元，最多可以買幾枝鉛筆？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '48', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '美美',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '可以',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '9枝',
#   'stype': ['每單位量', '有', '問分配']}]

# %%
solver.solve(correct_case[2])
# Out:
# {'Formula': '9000 / 110.0 = 81.0...90.0', 'My Answer': '81.0箱;90.0顆'}
# True

# %%
correct_case[26]
# Out:
# {'qid': '30873',
#  'sentence': '用減法算式把做法記下來：16顆巧克力，每4顆裝成一盒，可以裝成幾盒？',
#  'quantities': {'s1': [{'qtyid': 'E1',
#     'quantity': {'value': '16', 'unit': '顆', 'entity': '巧克力'},
#     'verb': '用',
#     'subject': None,
#     'object': None}],
#   's2': [{'qtyid': 'E2',
#     'quantity': {'value': '4', 'unit': '顆', 'entity': '巧克力'},
#     'verb': '裝成',
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E3',
#     'quantity': {'value': 1, 'unit': '盒', 'entity': '巧克力'},
#     'verb': '裝成',
#     'subject': None,
#     'object': None}],
#   's3': [{'qtyid': 'E4',
#     'quantity': {'value': '?', 'unit': '盒', 'entity': '巧克力'},
#     'verb': '裝成',
#     'subject': None,
#     'object': None}]},
#  'unitmaps': {'s2': [{'denominator': 'E2', 'numerator': 'E3'}]},
#  'answer': '4盒',
#  'stype': ['有', '每單位量', '問分配']}

# %%
solver.solve(correct_case[26])
# Out:
# {'Formula': '16 / 4.0 = 4.0', 'My Answer': '4.0盒'}
# True

# %%
def get_question_data(qid, data):
    for question in data:
        if question['qid'] == qid:
            return question
    return None  #

# %%
tmp = get_question_data("1MA0131110",data)

# %%
tmp
# Out:
# {'qid': '1MA0131110',
#  'sentence': '鉛筆一枝賣5元，美美帶了48元，最多可以買幾枝鉛筆？',
#  'quantities': {'s1': [{'qtyid': 'E1',
#     'quantity': {'value': 1, 'unit': '枝', 'entity': '鉛筆'},
#     'verb': '賣',
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E2',
#     'quantity': {'value': '5', 'unit': '元', 'entity': '鉛筆'},
#     'verb': '賣',
#     'subject': None,
#     'object': None}],
#   's2': [{'qtyid': 'E3',
#     'quantity': {'value': '48', 'unit': '元', 'entity': '鉛筆'},
#     'verb': '美美',
#     'subject': None,
#     'object': None}],
#   's3': [{'qtyid': 'E4',
#     'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#     'verb': '可以',
#     'subject': None,
#     'object': None}]},
#  'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#  'answer': '9枝',
#  'stype': ['每單位量', '有', '問分配']}

# %%
solver.solve(tmp)
# Out:
# {'Formula': '48 / 5.0 = 9.6', 'My Answer': '9.6枝'}
# False
