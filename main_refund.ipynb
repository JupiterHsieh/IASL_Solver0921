# %%
import sys
import os
import json

# Add the parent directory of the package to sys.path
sys.path.append(os.path.abspath('.'))
from solver.refund_solver import Refund_Solver

# Create an instance of Portion_Solver
solver = Refund_Solver()

# %%
path = "training_dataset/training_refund.json"

# %%
with open(path, 'r') as file:
    data = json.load(file)

# %%
def extract_data(data, stype_values):
        extracted_data = []
        for item in data:
            # Check if the 'stype' key exists and its value matches one of the specified values in stype_values
            if 'stype' in item and item['stype'] == stype_values:
                extracted_data.append(item)
        return extracted_data

# %%
import pandas as pd
from collections import Counter
stype_combinations = [tuple(d["stype"]) for d in data]
combination_counts = Counter(stype_combinations)

# Convert to DataFrame for better visualization
combination_df = pd.DataFrame(combination_counts.items(), columns=['Combination', 'Count'])
combination_df = combination_df.sort_values(by='Count', ascending=False)

combination_df
# Out:
#                  Combination  Count
# 1        (每單位量, 量變, 量變, 問找回)      8
# 0         (每單位量, 有, 量變, 問找回)      2
# 2  (每單位量, 每單位量, 量變, 量變, 問找回)      2
# 3              (量變, 量變, 問找回)      2
# 4           (有, 量變, 量變, 問找回)      1

# %%
extracted_data = data

# %%
# stype_list=[
#     ["每單位量","量變","量變","問找回"],
#     ["量變","量變","問找回"],
#     ["每單位量","每單位量","量變","量變","問找回"],
# ]
# stype = stype_list[0]
# extracted_data = extract_data(data,stype)

# %%
len(extracted_data)
# Out:
# 15

# %%
extracted_data[0]
# Out:
# {'qid': '52339',
#  'sentence': '展覽會門票每人80元，全班33人買票入場，付3000元，應該找回多少元？',
#  'quantities': {'s1': [{'qtyid': 'E1',
#     'quantity': {'value': '80', 'unit': '元', 'entity': '門票'},
#     'verb': None,
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E2',
#     'quantity': {'value': '每', 'unit': None, 'entity': '人'},
#     'verb': None,
#     'subject': None,
#     'object': None}],
#   's2': [{'qtyid': 'E3',
#     'quantity': {'value': '33', 'unit': None, 'entity': '人'},
#     'verb': None,
#     'subject': None,
#     'object': None}],
#   's3': [{'qtyid': 'E4',
#     'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#     'verb': '付',
#     'subject': None,
#     'object': None}],
#   's4': [{'qtyid': 'E5',
#     'quantity': {'value': '多少', 'unit': '元', 'entity': '人'},
#     'verb': '應該',
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E6',
#     'quantity': {'value': '多少', 'unit': '元', 'entity': '人'},
#     'verb': '找回',
#     'subject': None,
#     'object': None}]},
#  'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#  'answer': '360元',
#  'stype': ['每單位量', '有', '量變', '問找回']}

# %%
wrong_case = []

correct_case = []
wrong = 0
correct = 0
unsolve  = 0

for i in range(0, len(extracted_data)):
    try:
        if solver.solve(extracted_data[i]):
            correct_case.append(extracted_data[i])
            correct+=1
        else:
            wrong_case.append(extracted_data[i])
            wrong+=1

    except:
        wrong_case.append((extracted_data[i]))
        wrong+=1

print(f"Problems:{len(extracted_data)}, Correct:{correct}, Wrong:{wrong}, Accuracy:{correct/len(extracted_data)} ")
# Out:
# {'Question ID': '1MA0140466', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了250塊錢。250為已付。蘋果5元為單位價格。將購買的量與單位價格相乘得到應付價格。40顆蘋果 * 5 = 200 (應付價格)。計算應買總價格=200。將已付減去應付總價極為所求。250 - 200 = 50。", 'Formula': '', 'My Answer': 50, 'Solution': '50元'}
# {'Question ID': '1MA0140462', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了2500塊錢。2500為已付。票100元為單位價格。將購買的量與單位價格相乘得到應付價格。20張票 * 100 = 2000 (應付價格)。計算應買總價格=2000。將已付減去應付總價極為所求。2500 - 2000 = 500。", 'Formula': '', 'My Answer': 500, 'Solution': '500元'}
# {'Question ID': '52248', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了2000塊錢。2000為已付。棒棒糖24元為單位價格。將購買的量與單位價格相乘得到應付價格。64枝棒棒糖 * 24 = 1536 (應付價格)。計算應買總價格=1536。將已付減去應付總價極為所求。2000 - 1536 = 464。", 'Formula': '', 'My Answer': 464, 'Solution': '464元'}
# {'Question ID': '51837', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'拿'得知，付了1500塊錢。1500為已付。蛋糕26元為單位價格。蛋糕28元為單位價格。將購買的量與單位價格相乘得到應付價格。18個蛋糕 * 26 = 468 (應付價格)。23個蛋糕 * 26 = 598 (應付價格)。計算應買總價格=1066。將已付減去應付總價極為所求。1500 - 1066 = 434。", 'Formula': '', 'My Answer': 434, 'Solution': '388元'}
# {'Question ID': '50165', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了2000塊錢。2000為已付。鉛筆6元為單位價格。將購買的量與單位價格相乘得到應付價格。250枝鉛筆 * 6 = 1500 (應付價格)。計算應買總價格=1500。將已付減去應付總價極為所求。2000 - 1500 = 500。", 'Formula': '', 'My Answer': 500, 'Solution': '500元'}
# {'Question ID': '1MA0120703', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第2句裡的'付'得知，付了70塊錢。70為已付。鉛筆24元為單位價格。原子筆38元為單位價格。將購買的量與單位價格相乘得到應付價格。1盒鉛筆 * 24 = 24 (應付價格)。1枝原子筆 * 38 = 38 (應付價格)。計算應買總價格=62。將已付減去應付總價極為所求。70 - 62 = 8。", 'Formula': '', 'My Answer': 8, 'Solution': '8元'}
# {'Question ID': '1MA0120993', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'投'得知，付了70塊錢。70為已付。麵7元為單位價格。將購買的量與單位價格相乘得到應付價格。9包麵 * 7 = 63 (應付價格)。計算應買總價格=63。將已付減去應付總價極為所求。70 - 63 = 7。", 'Formula': '', 'My Answer': 7, 'Solution': '7元'}
# {'Question ID': '1MA0140436', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了12000塊錢。12000為已付。衣服506元為單位價格。將購買的量與單位價格相乘得到應付價格。23套衣服 * 506 = 11638 (應付價格)。計算應買總價格=11638。將已付減去應付總價極為所求。12000 - 11638 = 362。", 'Formula': '', 'My Answer': 362, 'Solution': '362元'}
# {'Question ID': '1MA0140470', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了2000塊錢。2000為已付。葡萄80元為單位價格。將購買的量與單位價格相乘得到應付價格。20串葡萄 * 80 = 1600 (應付價格)。計算應買總價格=1600。將已付減去應付總價極為所求。2000 - 1600 = 400。", 'Formula': '', 'My Answer': 400, 'Solution': '400元'}
# {'Question ID': '83906', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第4句裡的'付'得知，付了1000塊錢。1000為已付。午餐109元為單位價格。兒童餐96元為單位價格。將購買的量與單位價格相乘得到應付價格。2份兒童餐 * 96 = 192 (應付價格)。計算應買總價格=192。將已付減去應付總價極為所求。1000 - 192 = 808。", 'Formula': '', 'My Answer': 808, 'Solution': '590元'}
# Problems:15, Correct:8, Wrong:7, Accuracy:0.5333333333333333

# %%
correct_case
# Out:
# [{'qid': '1MA0140466',
#   'sentence': '一顆蘋果5元，小明買了40顆，付了250元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '顆', 'entity': '蘋果'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '蘋果'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '40', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '買',
#      'subject': '小明',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '250', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '小明',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蘋果'},
#      'verb': '找回',
#      'subject': '小明',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '50元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140462',
#   'sentence': '電影院票每張100元，哥哥訂了20張票，付2500元，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '票'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '100', 'unit': '元', 'entity': '票'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '20', 'unit': '張', 'entity': '票'},
#      'verb': '訂',
#      'subject': '哥哥',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2500', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '哥哥',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '門票'},
#      'verb': '應該',
#      'subject': '哥哥',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '門票'},
#      'verb': '找回',
#      'subject': '哥哥',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '500元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '52248',
#   'sentence': '一枝棒棒糖24元，老師買64枝，付2000元，應找回幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '棒棒糖'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '64', 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': '買',
#      'subject': '老師',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '老師',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '棒棒糖'},
#      'verb': '找回',
#      'subject': '老師',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '464元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '50165',
#   'sentence': '一枝鉛筆6元，買250枝鉛筆，付2000元，可找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '6', 'unit': '元', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '250', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '找回',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '500元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0120703',
#   'sentence': '志祺買一盒24元的鉛筆和一枝38元的原子筆，付了70元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': '盒', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '38', 'unit': '元', 'entity': '原子筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '原子筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None}],
#    's2': [{'qtyid': 'E5',
#      'quantity': {'value': '70', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '志祺',
#      'object': None}],
#    's3': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '原子筆'},
#      'verb': '找回',
#      'subject': '志祺',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'},
#     {'denominator': 'E1', 'numerator': 'E3'},
#     {'denominator': 'E1', 'numerator': 'E4'},
#     {'denominator': 'E2', 'numerator': 'E3'},
#     {'denominator': 'E2', 'numerator': 'E4'},
#     {'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '8元',
#   'stype': ['量變', '量變', '問找回']},
#  {'qid': '1MA0120993',
#   'sentence': '販賣機裡有一包7元的王子麵，小莉想買9包請同學吃，她投了70元，找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '元', 'entity': '麵'},
#      'verb': '有',
#      'subject': '販賣機',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '麵'},
#      'verb': '有',
#      'subject': '販賣機',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '買',
#      'subject': '小莉',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '請',
#      'subject': '小莉',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '吃',
#      'subject': '小莉',
#      'object': None}],
#    's3': [{'qtyid': 'E6',
#      'quantity': {'value': '70', 'unit': '元', 'entity': '麵'},
#      'verb': '投',
#      'subject': '她',
#      'object': None}],
#    's4': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '麵'},
#      'verb': '找回',
#      'subject': '她',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '7元',
#   'stype': ['有', '量變', '量變', '問找回']},
#  {'qid': '1MA0140436',
#   'sentence': '一套衣服賣506元，社團訂購了23套，付了12000元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '套', 'entity': '衣服'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '506', 'unit': '元', 'entity': '衣服'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '23', 'unit': '套', 'entity': '衣服'},
#      'verb': '訂購',
#      'subject': '社團',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '12000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '社團',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '衣服'},
#      'verb': '找回',
#      'subject': '社團',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '362元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140470',
#   'sentence': '一串葡萄80元，小紅買了20串，付了2000元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '串', 'entity': '葡萄'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '葡萄'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '20', 'unit': '串', 'entity': '葡萄'},
#      'verb': '買',
#      'subject': '小紅',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '小紅',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '葡萄'},
#      'verb': '找回',
#      'subject': '小紅',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '400元',
#   'stype': ['每單位量', '量變', '量變', '問找回']}]

# %%
wrong_case
# Out:
# [{'qid': '52339',
#   'sentence': '展覽會門票每人80元，全班33人買票入場，付3000元，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '門票'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '33', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '應該',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '找回',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '360元',
#   'stype': ['每單位量', '有', '量變', '問找回']},
#  {'qid': '51837',
#   'sentence': '一個草莓蛋糕26元，一個巧克力蛋糕28元，阿姨拿1500元，買了18個草莓蛋糕和23個巧克力蛋糕，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '26', 'unit': '元', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '28', 'unit': '元', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '1500', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '拿',
#      'subject': '阿姨',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '18', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '買',
#      'subject': '阿姨',
#      'object': None},
#     {'qtyid': 'E7',
#      'quantity': {'value': '23', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '買',
#      'subject': '阿姨',
#      'object': None}],
#    's5': [{'qtyid': 'E8',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '應該',
#      'subject': '阿姨',
#      'object': None},
#     {'qtyid': 'E9',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '找回',
#      'subject': '阿姨',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}],
#    's4': [{'denominator': 'E6', 'numerator': 'E7'}]},
#   'answer': '388元',
#   'stype': ['每單位量', '每單位量', '量變', '量變', '問找回']},
#  {'qid': '31519',
#   'sentence': '寫出算式算算看：亭傑在文具店買了8元的橡皮擦3塊、5元的鉛筆3枝，他付了一張百元鈔，應找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '元', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '塊', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '他',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '他',
#      'object': None}],
#    's3': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '找回',
#      'subject': '他',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'},
#     {'denominator': 'E1', 'numerator': 'E3'},
#     {'denominator': 'E1', 'numerator': 'E4'},
#     {'denominator': 'E2', 'numerator': 'E3'},
#     {'denominator': 'E2', 'numerator': 'E4'},
#     {'denominator': 'E3', 'numerator': 'E4'}],
#    's2': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '61元',
#   'stype': ['量變', '量變', '問找回']},
#  {'qid': '61335',
#   'sentence': '1顆蘋果賣24元，媽媽買了40顆蘋果，付一張千元鈔，可找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '1', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '蘋果'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '40', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '買',
#      'subject': '媽媽',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '找回',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '40元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140445',
#   'sentence': '一件T恤賣199元，阿姨買了15件，付了3000元，可以找回多少元？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': []},
#   'unitmaps': {},
#   'answer': '15元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140464',
#   'sentence': '科學館門票每人80元，學校團隊25人購票參訪，付2200元買票，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '25', 'unit': None, 'entity': '人'},
#      'verb': '訪',
#      'subject': '團隊',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '訪',
#      'subject': '團隊',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '2200', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '團隊',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '應該',
#      'subject': '團隊',
#      'object': None},
#     {'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '找回',
#      'subject': '團隊',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '200元',
#   'stype': ['每單位量', '有', '量變', '問找回']},
#  {'qid': '83906',
#   'sentence': '速食店的午餐一份109元，兒童餐一份96元，媽媽各買2份，付1000元，應找回幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '份', 'entity': '午餐'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '109', 'unit': '元', 'entity': '午餐'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': 1, 'unit': '份', 'entity': '兒童餐'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '96', 'unit': '元', 'entity': '兒童餐'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '2', 'unit': '份', 'entity': '兒童餐'},
#      'verb': '買',
#      'subject': '媽媽',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '1000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None}],
#    's5': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '兒童餐'},
#      'verb': '找回',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '590元',
#   'stype': ['每單位量', '每單位量', '量變', '量變', '問找回']}]

# %%
wrong_case[1]
# Out:
# {'qid': '51837',
#  'sentence': '一個草莓蛋糕26元，一個巧克力蛋糕28元，阿姨拿1500元，買了18個草莓蛋糕和23個巧克力蛋糕，應該找回多少元？',
#  'quantities': {'s1': [{'qtyid': 'E1',
#     'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#     'verb': None,
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E2',
#     'quantity': {'value': '26', 'unit': '元', 'entity': '蛋糕'},
#     'verb': None,
#     'subject': None,
#     'object': None}],
#   's2': [{'qtyid': 'E3',
#     'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#     'verb': None,
#     'subject': None,
#     'object': None},
#    {'qtyid': 'E4',
#     'quantity': {'value': '28', 'unit': '元', 'entity': '蛋糕'},
#     'verb': None,
#     'subject': None,
#     'object': None}],
#   's3': [{'qtyid': 'E5',
#     'quantity': {'value': '1500', 'unit': '元', 'entity': '蛋糕'},
#     'verb': '拿',
#     'subject': '阿姨',
#     'object': None}],
#   's4': [{'qtyid': 'E6',
#     'quantity': {'value': '18', 'unit': '個', 'entity': '蛋糕'},
#     'verb': '買',
#     'subject': '阿姨',
#     'object': None},
#    {'qtyid': 'E7',
#     'quantity': {'value': '23', 'unit': '個', 'entity': '蛋糕'},
#     'verb': '買',
#     'subject': '阿姨',
#     'object': None}],
#   's5': [{'qtyid': 'E8',
#     'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#     'verb': '應該',
#     'subject': '阿姨',
#     'object': None},
#    {'qtyid': 'E9',
#     'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#     'verb': '找回',
#     'subject': '阿姨',
#     'object': None}]},
#  'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#   's2': [{'denominator': 'E3', 'numerator': 'E4'}],
#   's4': [{'denominator': 'E6', 'numerator': 'E7'}]},
#  'answer': '388元',
#  'stype': ['每單位量', '每單位量', '量變', '量變', '問找回']}

# %%
solver.solve(wrong_case[1])
# Out:
# {'Question ID': '51837', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'拿'得知，付了1500塊錢。1500為已付。蛋糕26元為單位價格。蛋糕28元為單位價格。將購買的量與單位價格相乘得到應付價格。18個蛋糕 * 26 = 468 (應付價格)。23個蛋糕 * 26 = 598 (應付價格)。計算應買總價格=1066。將已付減去應付總價極為所求。1500 - 1066 = 434。", 'Formula': '', 'My Answer': 434, 'Solution': '388元'}
# False

# %%
solver.solve(correct_case[0])
# Out:
# {'Question ID': '1MA0140466', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'付'得知，付了250塊錢。250為已付。蘋果5元為單位價格。將購買的量與單位價格相乘得到應付價格。40顆蘋果 * 5 = 200 (應付價格)。計算應買總價格=200。將已付減去應付總價極為所求。250 - 200 = 50。", 'Formula': '', 'My Answer': 50, 'Solution': '50元'}
# True

# %%
correct_case
# Out:
# [{'qid': '1MA0140466',
#   'sentence': '一顆蘋果5元，小明買了40顆，付了250元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '顆', 'entity': '蘋果'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '蘋果'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '40', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '買',
#      'subject': '小明',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '250', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '小明',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蘋果'},
#      'verb': '找回',
#      'subject': '小明',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '50元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140462',
#   'sentence': '電影院票每張100元，哥哥訂了20張票，付2500元，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '票'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '100', 'unit': '元', 'entity': '票'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '20', 'unit': '張', 'entity': '票'},
#      'verb': '訂',
#      'subject': '哥哥',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2500', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '哥哥',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '門票'},
#      'verb': '應該',
#      'subject': '哥哥',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '門票'},
#      'verb': '找回',
#      'subject': '哥哥',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '500元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '52248',
#   'sentence': '一枝棒棒糖24元，老師買64枝，付2000元，應找回幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '棒棒糖'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '64', 'unit': '枝', 'entity': '棒棒糖'},
#      'verb': '買',
#      'subject': '老師',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '老師',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '棒棒糖'},
#      'verb': '找回',
#      'subject': '老師',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '464元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '50165',
#   'sentence': '一枝鉛筆6元，買250枝鉛筆，付2000元，可找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '6', 'unit': '元', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '250', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '找回',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '500元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0120703',
#   'sentence': '志祺買一盒24元的鉛筆和一枝38元的原子筆，付了70元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': '盒', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '38', 'unit': '元', 'entity': '原子筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 1, 'unit': '枝', 'entity': '原子筆'},
#      'verb': '買',
#      'subject': '志祺',
#      'object': None}],
#    's2': [{'qtyid': 'E5',
#      'quantity': {'value': '70', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '志祺',
#      'object': None}],
#    's3': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '原子筆'},
#      'verb': '找回',
#      'subject': '志祺',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'},
#     {'denominator': 'E1', 'numerator': 'E3'},
#     {'denominator': 'E1', 'numerator': 'E4'},
#     {'denominator': 'E2', 'numerator': 'E3'},
#     {'denominator': 'E2', 'numerator': 'E4'},
#     {'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '8元',
#   'stype': ['量變', '量變', '問找回']},
#  {'qid': '1MA0120993',
#   'sentence': '販賣機裡有一包7元的王子麵，小莉想買9包請同學吃，她投了70元，找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '元', 'entity': '麵'},
#      'verb': '有',
#      'subject': '販賣機',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': '包', 'entity': '麵'},
#      'verb': '有',
#      'subject': '販賣機',
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '買',
#      'subject': '小莉',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '請',
#      'subject': '小莉',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '9', 'unit': '包', 'entity': '麵'},
#      'verb': '吃',
#      'subject': '小莉',
#      'object': None}],
#    's3': [{'qtyid': 'E6',
#      'quantity': {'value': '70', 'unit': '元', 'entity': '麵'},
#      'verb': '投',
#      'subject': '她',
#      'object': None}],
#    's4': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '麵'},
#      'verb': '找回',
#      'subject': '她',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '7元',
#   'stype': ['有', '量變', '量變', '問找回']},
#  {'qid': '1MA0140436',
#   'sentence': '一套衣服賣506元，社團訂購了23套，付了12000元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '套', 'entity': '衣服'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '506', 'unit': '元', 'entity': '衣服'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '23', 'unit': '套', 'entity': '衣服'},
#      'verb': '訂購',
#      'subject': '社團',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '12000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '社團',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '衣服'},
#      'verb': '找回',
#      'subject': '社團',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '362元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140470',
#   'sentence': '一串葡萄80元，小紅買了20串，付了2000元，可以找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '串', 'entity': '葡萄'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '葡萄'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '20', 'unit': '串', 'entity': '葡萄'},
#      'verb': '買',
#      'subject': '小紅',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '2000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '小紅',
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '葡萄'},
#      'verb': '找回',
#      'subject': '小紅',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '400元',
#   'stype': ['每單位量', '量變', '量變', '問找回']}]

# %%
wrong_case
# Out:
# [{'qid': '52339',
#   'sentence': '展覽會門票每人80元，全班33人買票入場，付3000元，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '門票'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 1, 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '33', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '應該',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '找回',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '360元',
#   'stype': ['每單位量', '有', '量變', '問找回']},
#  {'qid': '51837',
#   'sentence': '一個草莓蛋糕26元，一個巧克力蛋糕28元，阿姨拿1500元，買了18個草莓蛋糕和23個巧克力蛋糕，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '26', 'unit': '元', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': 1, 'unit': '個', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '28', 'unit': '元', 'entity': '蛋糕'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '1500', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '拿',
#      'subject': '阿姨',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '18', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '買',
#      'subject': '阿姨',
#      'object': None},
#     {'qtyid': 'E7',
#      'quantity': {'value': '23', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '買',
#      'subject': '阿姨',
#      'object': None}],
#    's5': [{'qtyid': 'E8',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '應該',
#      'subject': '阿姨',
#      'object': None},
#     {'qtyid': 'E9',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '蛋糕'},
#      'verb': '找回',
#      'subject': '阿姨',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}],
#    's4': [{'denominator': 'E6', 'numerator': 'E7'}]},
#   'answer': '388元',
#   'stype': ['每單位量', '每單位量', '量變', '量變', '問找回']},
#  {'qid': '31519',
#   'sentence': '寫出算式算算看：亭傑在文具店買了8元的橡皮擦3塊、5元的鉛筆3枝，他付了一張百元鈔，應找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '元', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '塊', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '橡皮擦'},
#      'verb': '買',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '5', 'unit': '元', 'entity': '鉛筆'},
#      'verb': '買',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '他',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '他',
#      'object': None}],
#    's3': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '找回',
#      'subject': '他',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'},
#     {'denominator': 'E1', 'numerator': 'E3'},
#     {'denominator': 'E1', 'numerator': 'E4'},
#     {'denominator': 'E2', 'numerator': 'E3'},
#     {'denominator': 'E2', 'numerator': 'E4'},
#     {'denominator': 'E3', 'numerator': 'E4'}],
#    's2': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '61元',
#   'stype': ['量變', '量變', '問找回']},
#  {'qid': '61335',
#   'sentence': '1顆蘋果賣24元，媽媽買了40顆蘋果，付一張千元鈔，可找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '1', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '賣',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '24', 'unit': '元', 'entity': '蘋果'},
#      'verb': '賣',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '40', 'unit': '顆', 'entity': '蘋果'},
#      'verb': '買',
#      'subject': '媽媽',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': 1, 'unit': '張', 'entity': '鈔'},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '鈔'},
#      'verb': '找回',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '40元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140445',
#   'sentence': '一件T恤賣199元，阿姨買了15件，付了3000元，可以找回多少元？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': None,
#      'object': None}],
#    's4': []},
#   'unitmaps': {},
#   'answer': '15元',
#   'stype': ['每單位量', '量變', '量變', '問找回']},
#  {'qid': '1MA0140464',
#   'sentence': '科學館門票每人80元，學校團隊25人購票參訪，付2200元買票，應該找回多少元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '80', 'unit': '元', 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '25', 'unit': None, 'entity': '人'},
#      'verb': '訪',
#      'subject': '團隊',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '訪',
#      'subject': '團隊',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '2200', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '團隊',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '應該',
#      'subject': '團隊',
#      'object': None},
#     {'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '人'},
#      'verb': '找回',
#      'subject': '團隊',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '200元',
#   'stype': ['每單位量', '有', '量變', '問找回']},
#  {'qid': '83906',
#   'sentence': '速食店的午餐一份109元，兒童餐一份96元，媽媽各買2份，付1000元，應找回幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '份', 'entity': '午餐'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '109', 'unit': '元', 'entity': '午餐'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': 1, 'unit': '份', 'entity': '兒童餐'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '96', 'unit': '元', 'entity': '兒童餐'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '2', 'unit': '份', 'entity': '兒童餐'},
#      'verb': '買',
#      'subject': '媽媽',
#      'object': None}],
#    's4': [{'qtyid': 'E6',
#      'quantity': {'value': '1000', 'unit': '元', 'entity': None},
#      'verb': '付',
#      'subject': '媽媽',
#      'object': None}],
#    's5': [{'qtyid': 'E7',
#      'quantity': {'value': '?', 'unit': '元', 'entity': '兒童餐'},
#      'verb': '找回',
#      'subject': '媽媽',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '590元',
#   'stype': ['每單位量', '每單位量', '量變', '量變', '問找回']}]

# %%
solver.solve(wrong_case[1])
# Out:
# {'Question ID': '51837', 'Question Type': 'Single', 'Description': "此題為問找回，我們先找付的錢。可在第3句裡的'拿'得知，付了1500塊錢。1500為已付。蛋糕26元為單位價格。蛋糕28元為單位價格。將購買的量與單位價格相乘得到應付價格。18個蛋糕 * 26 = 468 (應付價格)。23個蛋糕 * 26 = 598 (應付價格)。計算應買總價格=1066。將已付減去應付總價極為所求。1500 - 1066 = 434。", 'Formula': '', 'My Answer': 434, 'Solution': '388元'}
# False

# %%
wrong_case[4]
# Out:
# {'qid': '1MA0140445',
#  'sentence': '一件T恤賣199元，阿姨買了15件，付了3000元，可以找回多少元？',
#  'quantities': {'s1': [],
#   's2': [],
#   's3': [{'qtyid': 'E1',
#     'quantity': {'value': '3000', 'unit': '元', 'entity': None},
#     'verb': '付',
#     'subject': None,
#     'object': None}],
#   's4': []},
#  'unitmaps': {},
#  'answer': '15元',
#  'stype': ['每單位量', '量變', '量變', '問找回']}
