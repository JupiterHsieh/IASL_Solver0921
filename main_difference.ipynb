# %%
import sys
import os
import json

# Add the parent directory of the package to sys.path
sys.path.append(os.path.abspath('.'))
from solver.difference_solver import Difference_Solver

# Create an instance of Portion_Solver
solver = Difference_Solver()

# %%
path = "training_dataset/training_set_difference.json"

# %%
with open(path, 'r') as file:
    data = json.load(file)

# %%
def extract_data(data, stype_values):
        extracted_data = []
        for item in data:
            # Check if the 'stype' key exists and its value matches one of the specified values in stype_values
            if 'stype' in item and item['stype'] == stype_values:
                extracted_data.append(item)
        return extracted_data

# %%
import pandas as pd
from collections import Counter
stype_combinations = [tuple(d["stype"]) for d in data]
combination_counts = Counter(stype_combinations)

# Convert to DataFrame for better visualization
combination_df = pd.DataFrame(combination_counts.items(), columns=['Combination', 'Count'])
combination_df = combination_df.sort_values(by='Count', ascending=False)

combination_df
# Out:
#                   Combination  Count
# 0                 (有, 有, 問相差)     42
# 6                    (有, 問相差)     28
# 8           (每單位量, 每單位量, 問相差)     20
# 4         (每單位量, 量變, 量變, 問相差)     11
# 1               (量變, 量變, 問相差)      9
# 10      (每單位量, 每單位量, 量變, 問相差)      6
# 12                (每單位量, 問相差)      5
# 5           (每單位量, 有, 有, 問相差)      5
# 9                   (量變, 問相差)      4
# 22             (有, 有, 有, 問相差)      4
# 11      (量變, 量變, 量變, 量變, 問相差)      3
# 15            (有, 有, 量變, 問相差)      3
# 23            (每單位量, 量變, 問相差)      2
# 2              (每單位量, 有, 問相差)      2
# 13           (有, 量變, 量變, 問相差)      2
# 14    (每單位量, 每單位量, 每單位量, 問相差)      2
# 7           (量變, 量變, 量變, 問相差)      1
# 20  (每單位量, 每單位量, 量變, 量變, 問相差)      1
# 21         (有, 平分, 每單位量, 問相差)      1
# 16    (每單位量, 每單位量, 問相差, 每單位量)      1
# 19   (每單位量, 量變, 量變, 問相差, 問相差)      1
# 18        (有, 有, 量變, 量變, 問相差)      1
# 17       (每單位量, 每單位量, 有, 問相差)      1
# 3           (有, 每單位量, 有, 問相差)      1
# 24          (有, 有, 每單位量, 問相差)      1

# %%
extracted_data = data

# %%
stype_list=[
    ["有","有","問相差"],
    ["有","問相差"],
]
stype = stype_list[0]
extracted_data = extract_data(data,stype)

# %%
extracted_data
# Out:
# [{'qid': '71324',
#   'sentence': '阿智和言言共有7.32盒筆芯。已知阿智有4.62盒，兩人的筆芯相差幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7.32', 'unit': '盒', 'entity': '芯'},
#      'verb': '共有',
#      'subject': '阿智',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4.62', 'unit': '盒', 'entity': '芯'},
#      'verb': '知',
#      'subject': '阿智',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '4.62', 'unit': '盒', 'entity': '芯'},
#      'verb': '有',
#      'subject': '阿智',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '芯'},
#      'verb': '相差',
#      'subject': '人|芯',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': '兩', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '1.92盒',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '71302',
#   'sentence': '小賢和小鈞共有5.65盒電池。已知小賢有2.85盒，兩人的電池相差幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '5.65', 'unit': '盒', 'entity': '電池'},
#      'verb': '共有',
#      'subject': '小賢|小鈞',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '知',
#      'subject': '小鈞',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '小',
#      'subject': '小鈞',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '有',
#      'subject': '小鈞',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '盒', 'entity': '電池'},
#      'verb': '相差',
#      'subject': '人|電池',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '兩', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '0.05盒',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70418',
#   'sentence': '甲道路長6公里，乙道路長4公里285公尺，兩條道路的長度相差幾公里幾公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '6', 'unit': '公里', 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4公里285公尺', 'unit': None, 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '兩', 'unit': '條', 'entity': '道路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾公里幾公尺', 'unit': None, 'entity': '道路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1公里715公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70261',
#   'sentence': '最便宜電信去年發出的拜年簡訊有636000000則，今年有471000000則，去年比今年多幾則？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '去年', 'unit': None, 'entity': '簡訊'},
#      'verb': '便宜',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '471000000', 'unit': '則', 'entity': '簡訊'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '則', 'entity': '簡訊'},
#      'verb': '多',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '165000000則',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61913',
#   'sentence': '門高3公尺，小媚身高是1.68公尺，門比小媚高多少公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '公尺', 'entity': '門'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '媚',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '是',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '多少', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': '門',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '多少', 'unit': '公尺', 'entity': '門'},
#      'verb': '媚',
#      'subject': '門',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '1.32公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70252',
#   'sentence': '進口奇異果有785000000顆，蘋果有365000000顆，奇異果比蘋果多幾顆？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '785000000', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '進口',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '365000000', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '有',
#      'subject': '蘋果',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '多',
#      'subject': '奇異果|蘋果',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '420000000顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70406',
#   'sentence': '甲道路長7公里，乙道路長5公里318公尺，兩條路的長度相差幾公里幾公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '公里', 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5公里318公尺', 'unit': None, 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '兩', 'unit': '條', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾公里幾公尺', 'unit': None, 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1公里682公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '72223',
#   'sentence': '自由路長2.064公里，仁愛路長2.604公里，兩條路的長度相差幾公里？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': '兩', 'unit': '條', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '幾', 'unit': '公里', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '0.54公里',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61644',
#   'sentence': '哥哥的書包重7公斤，弟弟的書包重5公斤，哥哥的書包比弟弟的書包重多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': '書包',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '多少', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': '書包|書包',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2公斤',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61909',
#   'sentence': '門高2公尺，小梅身高是1.32公尺，門比小梅高多少公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '2', 'unit': '公尺', 'entity': '門'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.32', 'unit': '公尺', 'entity': '門'},
#      'verb': '是',
#      'subject': '小梅',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '多少', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': '門',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '0.68公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '20491',
#   'sentence': '小玉有43張好棒貼紙，小英有37張，小玉比小英多幾張好棒貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '43', 'unit': '張', 'entity': '貼紙'},
#      'verb': '好棒',
#      'subject': '小玉',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '37', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小英',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '小玉|小英',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '貼紙'},
#      'verb': '好棒',
#      'subject': '小玉|小英',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '111273',
#   'sentence': '中央廣場有鴿子和狗84隻，已經知道共有184隻腳，鴿子和狗的數量相差幾隻？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '84', 'unit': '隻', 'entity': '鴿子'},
#      'verb': '有',
#      'subject': '中央廣場',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '184', 'unit': '隻', 'entity': '腳'},
#      'verb': '共有',
#      'subject': '中央廣場',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '隻', 'entity': '腳'},
#      'verb': '相差',
#      'subject': '鴿子|狗',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '68隻',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0150184',
#   'sentence': '青蛙卵的直徑約0.2公分，人類的紅血球直徑約0.0009公分，它們相差多少？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '0.2', 'unit': '公分', 'entity': '卵'},
#      'verb': '約',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.0009', 'unit': '公分', 'entity': '卵'},
#      'verb': '約',
#      'subject': '紅血球',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '多少', 'unit': None, 'entity': '它們'},
#      'verb': '相差',
#      'subject': '紅血球',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '0.1991公分',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0151073',
#   'sentence': '黃彩帶長2公尺，藍彩帶長4+(1/2)公尺，藍彩帶比黃彩帶長幾公尺？',
#   'quantities': {'s1': [],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '4+(1/2)', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '藍',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '幾', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '藍',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '長',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2+(1/2)公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '80167',
#   'sentence': '特大罐的鮮乳容量為2.9872公升，大罐的鮮乳容量為1.9563公升，兩種容量相差幾公升？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '2.9872', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '特大',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.9563', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '大',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '相差',
#      'subject': '容量',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '兩', 'unit': '種', 'entity': '容量'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1.0309公升',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110770',
#   'sentence': '安安有7顆糖，平平有11顆糖，平平比安安多幾顆糖？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '顆', 'entity': '糖'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '11', 'unit': '顆', 'entity': '糖'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '顆', 'entity': '糖'},
#      'verb': '多',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '4顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '917',
#   'sentence': '樹上有7隻鳥，電線桿上有4隻鳥，樹上的鳥比電線桿上的多幾隻？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '隻', 'entity': '鳥'},
#      'verb': '有',
#      'subject': '樹上',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '隻', 'entity': '鳥'},
#      'verb': '有',
#      'subject': '電線桿',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '隻', 'entity': '鳥'},
#      'verb': '上',
#      'subject': '鳥|電線桿',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '隻', 'entity': '鳥'},
#      'verb': '多',
#      'subject': '鳥|電線桿',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3隻',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110802',
#   'sentence': '阿杰有14臺小汽車，弟弟有2臺，阿杰比弟弟多幾臺小汽車？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '14', 'unit': '臺', 'entity': '汽車'},
#      'verb': '小',
#      'subject': '杰',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '臺', 'entity': '汽車'},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '臺', 'entity': '汽車'},
#      'verb': '多',
#      'subject': '阿杰|弟弟',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '臺', 'entity': '汽車'},
#      'verb': '小',
#      'subject': '阿杰|弟弟',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '12臺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1983',
#   'sentence': '妹妹有4張貼紙，姐姐有7張貼紙，姐姐比妹妹多幾張？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '妹妹',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '姐姐',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '姐姐|妹妹',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110649',
#   'sentence': '偉偉有8張貼紙，凱凱有14張貼紙，偉偉比凱凱少幾張貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '偉偉',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '14', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '凱凱',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '貼紙'},
#      'verb': '少',
#      'subject': '偉偉|凱凱',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '2104',
#   'sentence': '小惠有9枝鉛筆，小文有7枝鉛筆，小惠的鉛筆比小文的多幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '9', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '小惠',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '小惠',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '小',
#      'subject': '鉛筆',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '鉛筆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0111267',
#   'sentence': '哥哥有18元，弟弟有5元，哥哥比弟弟多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '18', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '哥哥',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '13元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '11852',
#   'sentence': '小明有76元，小輝有22元，小明比小輝多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '76', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '22', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小輝',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '54元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '926',
#   'sentence': '媽媽有10雙鞋子，爸爸有7雙鞋子，媽媽比爸爸多幾雙鞋子？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '10', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '有',
#      'subject': '媽媽',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '有',
#      'subject': '爸爸',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '多',
#      'subject': '媽媽|爸爸',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3雙',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0111133',
#   'sentence': '小文有8顆彈珠，小云有5顆彈珠，小文比小云多幾顆彈珠？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '有',
#      'subject': '小云',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '多',
#      'subject': '小文|小云',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '2403',
#   'sentence': '小靜有8張小熊貼紙，小美有2張，小靜比小美多幾張小熊貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小靜',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '小',
#      'subject': '小靜',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '美',
#      'subject': '小靜',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小靜',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '小靜|小美',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1211',
#   'sentence': '哥哥有7枝鉛筆，弟弟有3枝鉛筆，哥哥的鉛筆比弟弟的多幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '哥哥',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '鉛筆|弟弟',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '4枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1981',
#   'sentence': '妹妹有9枝原子筆，3枝鉛筆，原子筆比鉛筆多幾枝？',
#   'quantities': {'s1': [],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': '妹妹',
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '幾', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '原子筆|鉛筆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '928',
#   'sentence': '桃太郎有9張獎勵卡，豬小妹有7張獎勵卡，桃太郎的獎勵卡比豬小妹多幾張？',
#   'quantities': {'s1': [], 's2': [], 's3': []},
#   'unitmaps': {},
#   'answer': '2張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '929',
#   'sentence': '草莓蛋糕有4個，巧克力蛋糕有2個，草莓蛋糕比巧克力蛋糕多幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '有',
#      'subject': '蛋糕',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '多',
#      'subject': '蛋糕|蛋糕',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2個',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '20511',
#   'sentence': '今年爸爸41歲，小年12歲，兩人相差幾歲？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '今年', 'unit': None, 'entity': '爸爸'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '兩', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '29歲',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '22693',
#   'sentence': '小強有28元，阿力有40元，小強比阿力少幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '28', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小強',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '40', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小強',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '12元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120269',
#   'sentence': '君伊有72張遊戲卡，怡嫻有16張遊戲卡，怡嫻比君伊少幾張遊戲卡？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '72', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '君伊',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '16', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '怡嫻',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '遊戲'},
#      'verb': '少',
#      'subject': '怡嫻|君伊',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '56張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '22296',
#   'sentence': '阿宏有45張遊戲卡，東東有18張遊戲卡，東東的遊戲卡比阿宏的少幾張？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '45', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '阿宏',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '18', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '東東',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '遊戲'},
#      'verb': '卡',
#      'subject': '東東|遊戲',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '遊戲'},
#      'verb': '少',
#      'subject': '東東|遊戲',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '27張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120252',
#   'sentence': '喜餅盒裡圓形的餅乾有45片，方形的餅乾有29片，圓形的餅乾比方形多幾片？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '45', 'unit': '片', 'entity': '餅乾'},
#      'verb': '有',
#      'subject': '喜餅',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '29', 'unit': '片', 'entity': '餅乾'},
#      'verb': '有',
#      'subject': '餅乾',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '片', 'entity': '餅乾'},
#      'verb': '多',
#      'subject': '餅乾|比方',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '16片',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120278',
#   'sentence': '帆帆有19張榮譽卡，小昌有40張榮譽卡，小昌比帆帆多幾張榮譽卡？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '19', 'unit': '張', 'entity': '榮譽'},
#      'verb': '有',
#      'subject': '帆帆',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '40', 'unit': '張', 'entity': '榮譽'},
#      'verb': '有',
#      'subject': '帆帆',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '張', 'entity': '榮譽'},
#      'verb': '多',
#      'subject': '小昌|帆帆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '21張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120232',
#   'sentence': '公車上男生有11人，女生有23人，男生和女生相差幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '11', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '公車',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '23', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '女生',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '男生|女生',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '12人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61345',
#   'sentence': '秀晶有7246元，巧慧有496元，秀晶的錢是巧慧的幾倍又多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7246', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '496', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '倍'},
#      'verb': '是',
#      'subject': '秀晶',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '14倍多302元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '43045',
#   'sentence': '三年級的男生有205人，女生有176人，男生比女生多幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '205', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '男生',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '三', 'unit': '年', 'entity': '男生'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '176', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '女生',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '人'},
#      'verb': '多',
#      'subject': '男生|女生',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '29人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '43199',
#   'sentence': '哥哥重32公斤，弟弟重26公斤，兩人體重相差幾公斤？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': '兩', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '體重',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '幾', 'unit': '公斤', 'entity': '人'},
#      'verb': '相差',
#      'subject': '體重',
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '6公斤',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '42676',
#   'sentence': '棒球比賽第一場觀眾人數為7355人，第二場觀眾人數為9001人，這兩場觀眾人數相差幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '一', 'unit': '場', 'entity': '觀眾'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '7355', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '二', 'unit': '場', 'entity': '觀眾'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '9001', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '幾', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '這|觀眾',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '兩', 'unit': '場', 'entity': '觀眾'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}],
#    's3': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '1646人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '54128',
#   'sentence': '國語字典厚6.1公分，英語字典厚2.8公分，兩本書的厚度相差幾公分？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '6.1', 'unit': '公分', 'entity': '字典'},
#      'verb': '厚',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2.8', 'unit': '公分', 'entity': '字典'},
#      'verb': '厚',
#      'subject': '英語|字典',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '幾', 'unit': '公分', 'entity': '字典'},
#      'verb': '相差',
#      'subject': '書',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '兩', 'unit': '本', 'entity': '書'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '3.3公分',
#   'stype': ['有', '有', '問相差']}]

# %%
len(extracted_data)
# Out:
# 42

# %%
wrong_case = []
wrong = 0
correct = 0
unsolve  = 0

for i in range(0, len(extracted_data)):
    try:
        if solver.solve(extracted_data[i]):
            correct+=1
        else:
            wrong_case.append(extracted_data[i])
            wrong+=1

    except:
        wrong_case.append((extracted_data[i]))
        wrong+=1

print(f"Problems:{len(extracted_data)}, Correct:{correct}, Wrong:{wrong}, Accuracy:{correct/len(extracted_data)} ")
# Out:
# {'QuestionID': '71324', 'Variable': {'X1': {'value': '7.32', 'unit': '盒', 'entity': '芯', 'sentence': 's1', 'clue': None, 'verb': '共有', 'subject': '阿智', 'object': None}, 'X2': {'value': '4.62', 'unit': '盒', 'entity': '芯', 'sentence': 's2', 'clue': None, 'verb': '知', 'subject': '阿智', 'object': None}, 'X3': {'value': '4.62', 'unit': '盒', 'entity': '芯', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '阿智', 'object': None}, 'X4': {'value': '?', 'unit': '盒', 'entity': '芯', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '人|芯', 'object': None}, 'X5': {'value': 2, 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1.92盒', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '71302', 'Variable': {'X1': {'value': '5.65', 'unit': '盒', 'entity': '電池', 'sentence': 's1', 'clue': None, 'verb': '共有', 'subject': '小賢|小鈞', 'object': None}, 'X2': {'value': '2.85', 'unit': '盒', 'entity': '電池', 'sentence': 's2', 'clue': None, 'verb': '知', 'subject': '小鈞', 'object': None}, 'X3': {'value': '2.85', 'unit': '盒', 'entity': '電池', 'sentence': 's2', 'clue': None, 'verb': '小', 'subject': '小鈞', 'object': None}, 'X4': {'value': '2.85', 'unit': '盒', 'entity': '電池', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小鈞', 'object': None}, 'X5': {'value': '?', 'unit': '盒', 'entity': '電池', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '人|電池', 'object': None}, 'X6': {'value': 2, 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '0.05盒', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '70418', 'Variable': {'X1': {'value': '6', 'unit': '公里', 'entity': '道路', 'sentence': 's1', 'clue': None, 'verb': '長', 'subject': None, 'object': None}, 'X2': {'value': '?', 'unit': None, 'entity': '道路', 'sentence': 's2', 'clue': None, 'verb': '長', 'subject': None, 'object': None}, 'X3': {'value': 2, 'unit': '條', 'entity': '道路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}, 'X4': {'value': '?', 'unit': None, 'entity': '道路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1公里715公尺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '70261', 'Variable': {'X1': {'value': '?', 'unit': None, 'entity': '簡訊', 'sentence': 's1', 'clue': None, 'verb': '便宜', 'subject': None, 'object': None}, 'X2': {'value': '471000000', 'unit': '則', 'entity': '簡訊', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': '則', 'entity': '簡訊', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '165000000則', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '61913', 'Variable': {'X1': {'value': '3', 'unit': '公尺', 'entity': '門', 'sentence': 's1', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X2': {'value': '1.68', 'unit': '公尺', 'entity': '門', 'sentence': 's2', 'clue': None, 'verb': '小', 'subject': None, 'object': None}, 'X3': {'value': '1.68', 'unit': '公尺', 'entity': '門', 'sentence': 's2', 'clue': None, 'verb': '媚', 'subject': None, 'object': None}, 'X4': {'value': '1.68', 'unit': '公尺', 'entity': '門', 'sentence': 's2', 'clue': None, 'verb': '是', 'subject': None, 'object': None}, 'X5': {'value': '?', 'unit': '公尺', 'entity': '門', 'sentence': 's3', 'clue': None, 'verb': '小', 'subject': '門', 'object': None}, 'X6': {'value': '?', 'unit': '公尺', 'entity': '門', 'sentence': 's3', 'clue': None, 'verb': '媚', 'subject': '門', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1.32公尺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '70252', 'Variable': {'X1': {'value': '785000000', 'unit': '顆', 'entity': '奇異果', 'sentence': 's1', 'clue': None, 'verb': '進口', 'subject': None, 'object': None}, 'X2': {'value': '365000000', 'unit': '顆', 'entity': '奇異果', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '蘋果', 'object': None}, 'X3': {'value': '?', 'unit': '顆', 'entity': '奇異果', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '奇異果|蘋果', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '420000000顆', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '70406', 'Variable': {'X1': {'value': '7', 'unit': '公里', 'entity': '道路', 'sentence': 's1', 'clue': None, 'verb': '長', 'subject': None, 'object': None}, 'X2': {'value': '?', 'unit': None, 'entity': '道路', 'sentence': 's2', 'clue': None, 'verb': '長', 'subject': None, 'object': None}, 'X3': {'value': 2, 'unit': '條', 'entity': '路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}, 'X4': {'value': '?', 'unit': None, 'entity': '路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1公里682公尺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '72223', 'Variable': {'X1': {'value': 2, 'unit': '條', 'entity': '路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}, 'X2': {'value': '?', 'unit': '公里', 'entity': '路', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '0.54公里', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '61644', 'Variable': {'X1': {'value': '7', 'unit': '公斤', 'entity': '書包', 'sentence': 's1', 'clue': None, 'verb': '重', 'subject': None, 'object': None}, 'X2': {'value': '5', 'unit': '公斤', 'entity': '書包', 'sentence': 's2', 'clue': None, 'verb': '重', 'subject': '書包', 'object': None}, 'X3': {'value': '?', 'unit': '公斤', 'entity': '書包', 'sentence': 's3', 'clue': None, 'verb': '重', 'subject': '書包|書包', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '2公斤', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '61909', 'Variable': {'X1': {'value': '2', 'unit': '公尺', 'entity': '門', 'sentence': 's1', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X2': {'value': '1.32', 'unit': '公尺', 'entity': '門', 'sentence': 's2', 'clue': None, 'verb': '是', 'subject': '小梅', 'object': None}, 'X3': {'value': '?', 'unit': '公尺', 'entity': '門', 'sentence': 's3', 'clue': None, 'verb': '小', 'subject': '門', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '0.68公尺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '20491', 'Variable': {'X1': {'value': '43', 'unit': '張', 'entity': '貼紙', 'sentence': 's1', 'clue': None, 'verb': '好棒', 'subject': '小玉', 'object': None}, 'X2': {'value': '37', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小英', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '貼紙', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '小玉|小英', 'object': None}, 'X4': {'value': '?', 'unit': '張', 'entity': '貼紙', 'sentence': 's3', 'clue': None, 'verb': '好棒', 'subject': '小玉|小英', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '6張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '111273', 'Variable': {'X1': {'value': '84', 'unit': '隻', 'entity': '鴿子', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '中央廣場', 'object': None}, 'X2': {'value': '184', 'unit': '隻', 'entity': '腳', 'sentence': 's2', 'clue': None, 'verb': '共有', 'subject': '中央廣場', 'object': None}, 'X3': {'value': '?', 'unit': '隻', 'entity': '腳', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '鴿子|狗', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '68隻', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0150184', 'Variable': {'X1': {'value': '0.2', 'unit': '公分', 'entity': '卵', 'sentence': 's1', 'clue': None, 'verb': '約', 'subject': None, 'object': None}, 'X2': {'value': '0.0009', 'unit': '公分', 'entity': '卵', 'sentence': 's2', 'clue': None, 'verb': '約', 'subject': '紅血球', 'object': None}, 'X3': {'value': '?', 'unit': None, 'entity': '它們', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '紅血球', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '0.1991公分', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0151073', 'Variable': {'X1': {'value': '4+(1/2)', 'unit': '公尺', 'entity': '彩帶', 'sentence': 's2', 'clue': None, 'verb': '藍', 'subject': None, 'object': None}, 'X2': {'value': '?', 'unit': '公尺', 'entity': '彩帶', 'sentence': 's3', 'clue': None, 'verb': '藍', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': '公尺', 'entity': '彩帶', 'sentence': 's3', 'clue': None, 'verb': '長', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '2+(1/2)公尺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '80167', 'Variable': {'X1': {'value': '2.9872', 'unit': '公升', 'entity': '鮮乳', 'sentence': 's1', 'clue': None, 'verb': '特大', 'subject': None, 'object': None}, 'X2': {'value': '1.9563', 'unit': '公升', 'entity': '鮮乳', 'sentence': 's2', 'clue': None, 'verb': '大', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': '公升', 'entity': '鮮乳', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '容量', 'object': None}, 'X4': {'value': 2, 'unit': '種', 'entity': '容量', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1.0309公升', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0110770', 'Variable': {'X1': {'value': '7', 'unit': '顆', 'entity': '糖', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X2': {'value': '11', 'unit': '顆', 'entity': '糖', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': '顆', 'entity': '糖', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '4顆', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '917', 'Variable': {'X1': {'value': '7', 'unit': '隻', 'entity': '鳥', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '樹上', 'object': None}, 'X2': {'value': '4', 'unit': '隻', 'entity': '鳥', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '電線桿', 'object': None}, 'X3': {'value': '?', 'unit': '隻', 'entity': '鳥', 'sentence': 's3', 'clue': None, 'verb': '上', 'subject': '鳥|電線桿', 'object': None}, 'X4': {'value': '?', 'unit': '隻', 'entity': '鳥', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '鳥|電線桿', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '3隻', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0110802', 'Variable': {'X1': {'value': '14', 'unit': '臺', 'entity': '汽車', 'sentence': 's1', 'clue': None, 'verb': '小', 'subject': '杰', 'object': None}, 'X2': {'value': '2', 'unit': '臺', 'entity': '汽車', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '弟弟', 'object': None}, 'X3': {'value': '?', 'unit': '臺', 'entity': '汽車', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '阿杰|弟弟', 'object': None}, 'X4': {'value': '?', 'unit': '臺', 'entity': '汽車', 'sentence': 's3', 'clue': None, 'verb': '小', 'subject': '阿杰|弟弟', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '12臺', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1983', 'Variable': {'X1': {'value': '4', 'unit': '張', 'entity': '貼紙', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '妹妹', 'object': None}, 'X2': {'value': '7', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '姐姐', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '貼紙', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '姐姐|妹妹', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '3張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0110649', 'Variable': {'X1': {'value': '8', 'unit': '張', 'entity': '貼紙', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '偉偉', 'object': None}, 'X2': {'value': '14', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '凱凱', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '貼紙', 'sentence': 's3', 'clue': None, 'verb': '少', 'subject': '偉偉|凱凱', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '6張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '2104', 'Variable': {'X1': {'value': '9', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '小惠', 'object': None}, 'X2': {'value': '7', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小惠', 'object': None}, 'X3': {'value': '?', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's3', 'clue': None, 'verb': '小', 'subject': '鉛筆', 'object': None}, 'X4': {'value': '?', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '鉛筆', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '2枝', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0111267', 'Variable': {'X1': {'value': '18', 'unit': '元', 'entity': None, 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '哥哥', 'object': None}, 'X2': {'value': '5', 'unit': '元', 'entity': None, 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '弟弟', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '13元', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '11852', 'Variable': {'X1': {'value': '76', 'unit': '元', 'entity': None, 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X2': {'value': '22', 'unit': '元', 'entity': None, 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小輝', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '54元', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '926', 'Variable': {'X1': {'value': '10', 'unit': '雙', 'entity': '鞋子', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '媽媽', 'object': None}, 'X2': {'value': '7', 'unit': '雙', 'entity': '鞋子', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '爸爸', 'object': None}, 'X3': {'value': '?', 'unit': '雙', 'entity': '鞋子', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '媽媽|爸爸', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '3雙', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0111133', 'Variable': {'X1': {'value': '8', 'unit': '顆', 'entity': '彈珠', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X2': {'value': '5', 'unit': '顆', 'entity': '彈珠', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小云', 'object': None}, 'X3': {'value': '?', 'unit': '顆', 'entity': '彈珠', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '小文|小云', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '3顆', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '2403', 'Variable': {'X1': {'value': '8', 'unit': '張', 'entity': '貼紙', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '小靜', 'object': None}, 'X2': {'value': '2', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '小', 'subject': '小靜', 'object': None}, 'X3': {'value': '2', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '美', 'subject': '小靜', 'object': None}, 'X4': {'value': '2', 'unit': '張', 'entity': '貼紙', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小靜', 'object': None}, 'X5': {'value': '?', 'unit': '張', 'entity': '貼紙', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '小靜|小美', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '6張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1211', 'Variable': {'X1': {'value': '7', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '哥哥', 'object': None}, 'X2': {'value': '3', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '弟弟', 'object': None}, 'X3': {'value': '?', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '鉛筆|弟弟', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '4枝', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1981', 'Variable': {'X1': {'value': '3', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's2', 'clue': None, 'verb': None, 'subject': '妹妹', 'object': None}, 'X2': {'value': '?', 'unit': '枝', 'entity': '鉛筆', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '原子筆|鉛筆', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '6枝', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '928', 'Variable': {}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '2張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '929', 'Variable': {'X1': {'value': '4', 'unit': '個', 'entity': '蛋糕', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X2': {'value': '2', 'unit': '個', 'entity': '蛋糕', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '蛋糕', 'object': None}, 'X3': {'value': '?', 'unit': '個', 'entity': '蛋糕', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '蛋糕|蛋糕', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '2個', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '20511', 'Variable': {'X1': {'value': '?', 'unit': None, 'entity': '爸爸', 'sentence': 's1', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X2': {'value': 2, 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '29歲', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '22693', 'Variable': {'X1': {'value': '28', 'unit': '元', 'entity': None, 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '小強', 'object': None}, 'X2': {'value': '40', 'unit': '元', 'entity': None, 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '小強', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '12元', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0120269', 'Variable': {'X1': {'value': '72', 'unit': '張', 'entity': '遊戲', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '君伊', 'object': None}, 'X2': {'value': '16', 'unit': '張', 'entity': '遊戲', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '怡嫻', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '遊戲', 'sentence': 's3', 'clue': None, 'verb': '少', 'subject': '怡嫻|君伊', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '56張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '22296', 'Variable': {'X1': {'value': '45', 'unit': '張', 'entity': '遊戲', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '阿宏', 'object': None}, 'X2': {'value': '18', 'unit': '張', 'entity': '遊戲', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '東東', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '遊戲', 'sentence': 's3', 'clue': None, 'verb': '卡', 'subject': '東東|遊戲', 'object': None}, 'X4': {'value': '?', 'unit': '張', 'entity': '遊戲', 'sentence': 's3', 'clue': None, 'verb': '少', 'subject': '東東|遊戲', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '27張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0120252', 'Variable': {'X1': {'value': '45', 'unit': '片', 'entity': '餅乾', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '喜餅', 'object': None}, 'X2': {'value': '29', 'unit': '片', 'entity': '餅乾', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '餅乾', 'object': None}, 'X3': {'value': '?', 'unit': '片', 'entity': '餅乾', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '餅乾|比方', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '16片', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0120278', 'Variable': {'X1': {'value': '19', 'unit': '張', 'entity': '榮譽', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '帆帆', 'object': None}, 'X2': {'value': '40', 'unit': '張', 'entity': '榮譽', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '帆帆', 'object': None}, 'X3': {'value': '?', 'unit': '張', 'entity': '榮譽', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '小昌|帆帆', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '21張', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '1MA0120232', 'Variable': {'X1': {'value': '11', 'unit': None, 'entity': '人', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '公車', 'object': None}, 'X2': {'value': '23', 'unit': None, 'entity': '人', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '女生', 'object': None}, 'X3': {'value': '?', 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '男生|女生', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '12人', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '61345', 'Variable': {'X1': {'value': '7246', 'unit': '元', 'entity': None, 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X2': {'value': '496', 'unit': '元', 'entity': None, 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X3': {'value': '?', 'unit': None, 'entity': '倍', 'sentence': 's3', 'clue': None, 'verb': '是', 'subject': '秀晶', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '14倍多302元', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '43045', 'Variable': {'X1': {'value': '205', 'unit': None, 'entity': '人', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': '男生', 'object': None}, 'X2': {'value': 3, 'unit': '年', 'entity': '男生', 'sentence': 's1', 'clue': None, 'verb': '有', 'subject': None, 'object': None}, 'X3': {'value': '176', 'unit': None, 'entity': '人', 'sentence': 's2', 'clue': None, 'verb': '有', 'subject': '女生', 'object': None}, 'X4': {'value': '?', 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '多', 'subject': '男生|女生', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '29人', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '43199', 'Variable': {'X1': {'value': 2, 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '體重', 'object': None}, 'X2': {'value': '?', 'unit': '公斤', 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '體重', 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '6公斤', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '42676', 'Variable': {'X1': {'value': 1, 'unit': '場', 'entity': '觀眾', 'sentence': 's1', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X2': {'value': '7355', 'unit': None, 'entity': '人', 'sentence': 's1', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X3': {'value': 2, 'unit': '場', 'entity': '觀眾', 'sentence': 's2', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X4': {'value': '9001', 'unit': None, 'entity': '人', 'sentence': 's2', 'clue': None, 'verb': None, 'subject': None, 'object': None}, 'X5': {'value': '?', 'unit': None, 'entity': '人', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '這|觀眾', 'object': None}, 'X6': {'value': 2, 'unit': '場', 'entity': '觀眾', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '1646人', '第一比較物': None, '第二比較物': None, '共有': None}
# {'QuestionID': '54128', 'Variable': {'X1': {'value': '6.1', 'unit': '公分', 'entity': '字典', 'sentence': 's1', 'clue': None, 'verb': '厚', 'subject': None, 'object': None}, 'X2': {'value': '2.8', 'unit': '公分', 'entity': '字典', 'sentence': 's2', 'clue': None, 'verb': '厚', 'subject': '英語|字典', 'object': None}, 'X3': {'value': '?', 'unit': '公分', 'entity': '字典', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': '書', 'object': None}, 'X4': {'value': 2, 'unit': '本', 'entity': '書', 'sentence': 's3', 'clue': None, 'verb': '相差', 'subject': None, 'object': None}}, 'stype': ['有', '有', '問相差'], 'Description': '', 'Formula': '', 'Answer': '3.3公分', '第一比較物': None, '第二比較物': None, '共有': None}
# Problems:42, Correct:0, Wrong:42, Accuracy:0.0

# %%
extracted_data
# Out:
# [{'qid': '71324',
#   'sentence': '阿智和言言共有7.32盒筆芯。已知阿智有4.62盒，兩人的筆芯相差幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7.32', 'unit': '盒', 'entity': '芯'},
#      'verb': '共有',
#      'subject': '阿智',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4.62', 'unit': '盒', 'entity': '芯'},
#      'verb': '知',
#      'subject': '阿智',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '4.62', 'unit': '盒', 'entity': '芯'},
#      'verb': '有',
#      'subject': '阿智',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '盒', 'entity': '芯'},
#      'verb': '相差',
#      'subject': '人|芯',
#      'object': None},
#     {'qtyid': 'E5',
#      'quantity': {'value': 2, 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E4', 'numerator': 'E5'}]},
#   'answer': '1.92盒',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '71302',
#   'sentence': '小賢和小鈞共有5.65盒電池。已知小賢有2.85盒，兩人的電池相差幾盒？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '5.65', 'unit': '盒', 'entity': '電池'},
#      'verb': '共有',
#      'subject': '小賢|小鈞',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '知',
#      'subject': '小鈞',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '小',
#      'subject': '小鈞',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '2.85', 'unit': '盒', 'entity': '電池'},
#      'verb': '有',
#      'subject': '小鈞',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '盒', 'entity': '電池'},
#      'verb': '相差',
#      'subject': '人|電池',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': 2, 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '0.05盒',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70418',
#   'sentence': '甲道路長6公里，乙道路長4公里285公尺，兩條道路的長度相差幾公里幾公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '6', 'unit': '公里', 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': None, 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': 2, 'unit': '條', 'entity': '道路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': None, 'entity': '道路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1公里715公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70261',
#   'sentence': '最便宜電信去年發出的拜年簡訊有636000000則，今年有471000000則，去年比今年多幾則？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '?', 'unit': None, 'entity': '簡訊'},
#      'verb': '便宜',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '471000000', 'unit': '則', 'entity': '簡訊'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '則', 'entity': '簡訊'},
#      'verb': '多',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '165000000則',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61913',
#   'sentence': '門高3公尺，小媚身高是1.68公尺，門比小媚高多少公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '公尺', 'entity': '門'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '媚',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '1.68', 'unit': '公尺', 'entity': '門'},
#      'verb': '是',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': '門',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': '?', 'unit': '公尺', 'entity': '門'},
#      'verb': '媚',
#      'subject': '門',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '1.32公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70252',
#   'sentence': '進口奇異果有785000000顆，蘋果有365000000顆，奇異果比蘋果多幾顆？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '785000000', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '進口',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '365000000', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '有',
#      'subject': '蘋果',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '顆', 'entity': '奇異果'},
#      'verb': '多',
#      'subject': '奇異果|蘋果',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '420000000顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '70406',
#   'sentence': '甲道路長7公里，乙道路長5公里318公尺，兩條路的長度相差幾公里幾公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '公里', 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': None, 'entity': '道路'},
#      'verb': '長',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': 2, 'unit': '條', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': None, 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1公里682公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '72223',
#   'sentence': '自由路長2.064公里，仁愛路長2.604公里，兩條路的長度相差幾公里？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': 2, 'unit': '條', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': '公里', 'entity': '路'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '0.54公里',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61644',
#   'sentence': '哥哥的書包重7公斤，弟弟的書包重5公斤，哥哥的書包比弟弟的書包重多少公斤？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': '書包',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '公斤', 'entity': '書包'},
#      'verb': '重',
#      'subject': '書包|書包',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2公斤',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61909',
#   'sentence': '門高2公尺，小梅身高是1.32公尺，門比小梅高多少公尺？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '2', 'unit': '公尺', 'entity': '門'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.32', 'unit': '公尺', 'entity': '門'},
#      'verb': '是',
#      'subject': '小梅',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '公尺', 'entity': '門'},
#      'verb': '小',
#      'subject': '門',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '0.68公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '20491',
#   'sentence': '小玉有43張好棒貼紙，小英有37張，小玉比小英多幾張好棒貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '43', 'unit': '張', 'entity': '貼紙'},
#      'verb': '好棒',
#      'subject': '小玉',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '37', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小英',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '小玉|小英',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '貼紙'},
#      'verb': '好棒',
#      'subject': '小玉|小英',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '111273',
#   'sentence': '中央廣場有鴿子和狗84隻，已經知道共有184隻腳，鴿子和狗的數量相差幾隻？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '84', 'unit': '隻', 'entity': '鴿子'},
#      'verb': '有',
#      'subject': '中央廣場',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '184', 'unit': '隻', 'entity': '腳'},
#      'verb': '共有',
#      'subject': '中央廣場',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '隻', 'entity': '腳'},
#      'verb': '相差',
#      'subject': '鴿子|狗',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '68隻',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0150184',
#   'sentence': '青蛙卵的直徑約0.2公分，人類的紅血球直徑約0.0009公分，它們相差多少？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '0.2', 'unit': '公分', 'entity': '卵'},
#      'verb': '約',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '0.0009', 'unit': '公分', 'entity': '卵'},
#      'verb': '約',
#      'subject': '紅血球',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': None, 'entity': '它們'},
#      'verb': '相差',
#      'subject': '紅血球',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '0.1991公分',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0151073',
#   'sentence': '黃彩帶長2公尺，藍彩帶長4+(1/2)公尺，藍彩帶比黃彩帶長幾公尺？',
#   'quantities': {'s1': [],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '4+(1/2)', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '藍',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '藍',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '公尺', 'entity': '彩帶'},
#      'verb': '長',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2+(1/2)公尺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '80167',
#   'sentence': '特大罐的鮮乳容量為2.9872公升，大罐的鮮乳容量為1.9563公升，兩種容量相差幾公升？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '2.9872', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '特大',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '1.9563', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '大',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '公升', 'entity': '鮮乳'},
#      'verb': '相差',
#      'subject': '容量',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 2, 'unit': '種', 'entity': '容量'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '1.0309公升',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110770',
#   'sentence': '安安有7顆糖，平平有11顆糖，平平比安安多幾顆糖？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '顆', 'entity': '糖'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '11', 'unit': '顆', 'entity': '糖'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '顆', 'entity': '糖'},
#      'verb': '多',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '4顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '917',
#   'sentence': '樹上有7隻鳥，電線桿上有4隻鳥，樹上的鳥比電線桿上的多幾隻？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '隻', 'entity': '鳥'},
#      'verb': '有',
#      'subject': '樹上',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '4', 'unit': '隻', 'entity': '鳥'},
#      'verb': '有',
#      'subject': '電線桿',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '隻', 'entity': '鳥'},
#      'verb': '上',
#      'subject': '鳥|電線桿',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '隻', 'entity': '鳥'},
#      'verb': '多',
#      'subject': '鳥|電線桿',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3隻',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110802',
#   'sentence': '阿杰有14臺小汽車，弟弟有2臺，阿杰比弟弟多幾臺小汽車？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '14', 'unit': '臺', 'entity': '汽車'},
#      'verb': '小',
#      'subject': '杰',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '臺', 'entity': '汽車'},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '臺', 'entity': '汽車'},
#      'verb': '多',
#      'subject': '阿杰|弟弟',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '臺', 'entity': '汽車'},
#      'verb': '小',
#      'subject': '阿杰|弟弟',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '12臺',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1983',
#   'sentence': '妹妹有4張貼紙，姐姐有7張貼紙，姐姐比妹妹多幾張？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '妹妹',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '姐姐',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '姐姐|妹妹',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0110649',
#   'sentence': '偉偉有8張貼紙，凱凱有14張貼紙，偉偉比凱凱少幾張貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '偉偉',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '14', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '凱凱',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '貼紙'},
#      'verb': '少',
#      'subject': '偉偉|凱凱',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '2104',
#   'sentence': '小惠有9枝鉛筆，小文有7枝鉛筆，小惠的鉛筆比小文的多幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '9', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '小惠',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '小惠',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '小',
#      'subject': '鉛筆',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '鉛筆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0111267',
#   'sentence': '哥哥有18元，弟弟有5元，哥哥比弟弟多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '18', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '哥哥',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '13元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '11852',
#   'sentence': '小明有76元，小輝有22元，小明比小輝多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '76', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '22', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小輝',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '54元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '926',
#   'sentence': '媽媽有10雙鞋子，爸爸有7雙鞋子，媽媽比爸爸多幾雙鞋子？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '10', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '有',
#      'subject': '媽媽',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '7', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '有',
#      'subject': '爸爸',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '雙', 'entity': '鞋子'},
#      'verb': '多',
#      'subject': '媽媽|爸爸',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3雙',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0111133',
#   'sentence': '小文有8顆彈珠，小云有5顆彈珠，小文比小云多幾顆彈珠？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '5', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '有',
#      'subject': '小云',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '顆', 'entity': '彈珠'},
#      'verb': '多',
#      'subject': '小文|小云',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '3顆',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '2403',
#   'sentence': '小靜有8張小熊貼紙，小美有2張，小靜比小美多幾張小熊貼紙？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '8', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小靜',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '小',
#      'subject': '小靜',
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '美',
#      'subject': '小靜',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '2', 'unit': '張', 'entity': '貼紙'},
#      'verb': '有',
#      'subject': '小靜',
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '貼紙'},
#      'verb': '多',
#      'subject': '小靜|小美',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1211',
#   'sentence': '哥哥有7枝鉛筆，弟弟有3枝鉛筆，哥哥的鉛筆比弟弟的多幾枝？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '哥哥',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '有',
#      'subject': '弟弟',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '鉛筆|弟弟',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '4枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1981',
#   'sentence': '妹妹有9枝原子筆，3枝鉛筆，原子筆比鉛筆多幾枝？',
#   'quantities': {'s1': [],
#    's2': [{'qtyid': 'E1',
#      'quantity': {'value': '3', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': None,
#      'subject': '妹妹',
#      'object': None}],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': '枝', 'entity': '鉛筆'},
#      'verb': '多',
#      'subject': '原子筆|鉛筆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '6枝',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '928',
#   'sentence': '桃太郎有9張獎勵卡，豬小妹有7張獎勵卡，桃太郎的獎勵卡比豬小妹多幾張？',
#   'quantities': {'s1': [], 's2': [], 's3': []},
#   'unitmaps': {},
#   'answer': '2張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '929',
#   'sentence': '草莓蛋糕有4個，巧克力蛋糕有2個，草莓蛋糕比巧克力蛋糕多幾個？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '4', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '有',
#      'subject': '蛋糕',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '個', 'entity': '蛋糕'},
#      'verb': '多',
#      'subject': '蛋糕|蛋糕',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '2個',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '20511',
#   'sentence': '今年爸爸41歲，小年12歲，兩人相差幾歲？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '?', 'unit': None, 'entity': '爸爸'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [],
#    's3': [{'qtyid': 'E2',
#      'quantity': {'value': 2, 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E2', 'numerator': 'E3'}]},
#   'answer': '29歲',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '22693',
#   'sentence': '小強有28元，阿力有40元，小強比阿力少幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '28', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小強',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '40', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': '小強',
#      'object': None}],
#    's3': []},
#   'unitmaps': {},
#   'answer': '12元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120269',
#   'sentence': '君伊有72張遊戲卡，怡嫻有16張遊戲卡，怡嫻比君伊少幾張遊戲卡？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '72', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '君伊',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '16', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '怡嫻',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '遊戲'},
#      'verb': '少',
#      'subject': '怡嫻|君伊',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '56張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '22296',
#   'sentence': '阿宏有45張遊戲卡，東東有18張遊戲卡，東東的遊戲卡比阿宏的少幾張？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '45', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '阿宏',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '18', 'unit': '張', 'entity': '遊戲'},
#      'verb': '有',
#      'subject': '東東',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '遊戲'},
#      'verb': '卡',
#      'subject': '東東|遊戲',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '遊戲'},
#      'verb': '少',
#      'subject': '東東|遊戲',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '27張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120252',
#   'sentence': '喜餅盒裡圓形的餅乾有45片，方形的餅乾有29片，圓形的餅乾比方形多幾片？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '45', 'unit': '片', 'entity': '餅乾'},
#      'verb': '有',
#      'subject': '喜餅',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '29', 'unit': '片', 'entity': '餅乾'},
#      'verb': '有',
#      'subject': '餅乾',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '片', 'entity': '餅乾'},
#      'verb': '多',
#      'subject': '餅乾|比方',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '16片',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120278',
#   'sentence': '帆帆有19張榮譽卡，小昌有40張榮譽卡，小昌比帆帆多幾張榮譽卡？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '19', 'unit': '張', 'entity': '榮譽'},
#      'verb': '有',
#      'subject': '帆帆',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '40', 'unit': '張', 'entity': '榮譽'},
#      'verb': '有',
#      'subject': '帆帆',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '張', 'entity': '榮譽'},
#      'verb': '多',
#      'subject': '小昌|帆帆',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '21張',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '1MA0120232',
#   'sentence': '公車上男生有11人，女生有23人，男生和女生相差幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '11', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '公車',
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '23', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '女生',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '男生|女生',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '12人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '61345',
#   'sentence': '秀晶有7246元，巧慧有496元，秀晶的錢是巧慧的幾倍又多幾元？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '7246', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '496', 'unit': '元', 'entity': None},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': None, 'entity': '倍'},
#      'verb': '是',
#      'subject': '秀晶',
#      'object': None}]},
#   'unitmaps': {},
#   'answer': '14倍多302元',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '43045',
#   'sentence': '三年級的男生有205人，女生有176人，男生比女生多幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '205', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '男生',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': 3, 'unit': '年', 'entity': '男生'},
#      'verb': '有',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': '176', 'unit': None, 'entity': '人'},
#      'verb': '有',
#      'subject': '女生',
#      'object': None}],
#    's3': [{'qtyid': 'E4',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '多',
#      'subject': '男生|女生',
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '29人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '43199',
#   'sentence': '哥哥重32公斤，弟弟重26公斤，兩人體重相差幾公斤？',
#   'quantities': {'s1': [],
#    's2': [],
#    's3': [{'qtyid': 'E1',
#      'quantity': {'value': 2, 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '體重',
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '?', 'unit': '公斤', 'entity': '人'},
#      'verb': '相差',
#      'subject': '體重',
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E1', 'numerator': 'E2'}]},
#   'answer': '6公斤',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '42676',
#   'sentence': '棒球比賽第一場觀眾人數為7355人，第二場觀眾人數為9001人，這兩場觀眾人數相差幾人？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': 1, 'unit': '場', 'entity': '觀眾'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E2',
#      'quantity': {'value': '7355', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E3',
#      'quantity': {'value': 2, 'unit': '場', 'entity': '觀眾'},
#      'verb': None,
#      'subject': None,
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': '9001', 'unit': None, 'entity': '人'},
#      'verb': None,
#      'subject': None,
#      'object': None}],
#    's3': [{'qtyid': 'E5',
#      'quantity': {'value': '?', 'unit': None, 'entity': '人'},
#      'verb': '相差',
#      'subject': '這|觀眾',
#      'object': None},
#     {'qtyid': 'E6',
#      'quantity': {'value': 2, 'unit': '場', 'entity': '觀眾'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s1': [{'denominator': 'E1', 'numerator': 'E2'}],
#    's2': [{'denominator': 'E3', 'numerator': 'E4'}],
#    's3': [{'denominator': 'E5', 'numerator': 'E6'}]},
#   'answer': '1646人',
#   'stype': ['有', '有', '問相差']},
#  {'qid': '54128',
#   'sentence': '國語字典厚6.1公分，英語字典厚2.8公分，兩本書的厚度相差幾公分？',
#   'quantities': {'s1': [{'qtyid': 'E1',
#      'quantity': {'value': '6.1', 'unit': '公分', 'entity': '字典'},
#      'verb': '厚',
#      'subject': None,
#      'object': None}],
#    's2': [{'qtyid': 'E2',
#      'quantity': {'value': '2.8', 'unit': '公分', 'entity': '字典'},
#      'verb': '厚',
#      'subject': '英語|字典',
#      'object': None}],
#    's3': [{'qtyid': 'E3',
#      'quantity': {'value': '?', 'unit': '公分', 'entity': '字典'},
#      'verb': '相差',
#      'subject': '書',
#      'object': None},
#     {'qtyid': 'E4',
#      'quantity': {'value': 2, 'unit': '本', 'entity': '書'},
#      'verb': '相差',
#      'subject': None,
#      'object': None}]},
#   'unitmaps': {'s3': [{'denominator': 'E3', 'numerator': 'E4'}]},
#   'answer': '3.3公分',
#   'stype': ['有', '有', '問相差']}]
